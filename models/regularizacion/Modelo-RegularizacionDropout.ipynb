# %% [markdown]
# <a href="https://colab.research.google.com/github/dangalmar/TFG_Imagenes_Medicas/blob/main/Tratamiento_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler

import os

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from glob import glob
import seaborn as sns
from PIL import Image

# %%
folder_benign_train = '../../new_data/train/benign'
folder_malignant_train = '../../new_data/train/malignant'

folder_benign_test = '../../new_data/test/benign'
folder_malignant_test = '../../new_data/test/malignant'

read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))

# Load in training pictures
ims_benign = [read(os.path.join(folder_benign_train, filename)) for filename in os.listdir(folder_benign_train)]
X_benign = np.array(ims_benign, dtype='uint8')
ims_malignant = [read(os.path.join(folder_malignant_train, filename)) for filename in os.listdir(folder_malignant_train)]
X_malignant = np.array(ims_malignant, dtype='uint8')

# Load in testing pictures
ims_benign = [read(os.path.join(folder_benign_test, filename)) for filename in os.listdir(folder_benign_test)]
X_benign_test = np.array(ims_benign, dtype='uint8')
ims_malignant = [read(os.path.join(folder_malignant_test, filename)) for filename in os.listdir(folder_malignant_test)]
X_malignant_test = np.array(ims_malignant, dtype='uint8')

# Create labels
y_benign = np.zeros(X_benign.shape[0])
y_malignant = np.ones(X_malignant.shape[0])

y_benign_test = np.zeros(X_benign_test.shape[0])
y_malignant_test = np.ones(X_malignant_test.shape[0])


# Merge data
X_train = np.concatenate((X_benign, X_malignant), axis = 0)
y_train = np.concatenate((y_benign, y_malignant), axis = 0)

X_test = np.concatenate((X_benign_test, X_malignant_test), axis = 0)
y_test = np.concatenate((y_benign_test, y_malignant_test), axis = 0)

# Shuffle data
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
y_train = y_train[s]

s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
y_test = y_test[s]

# %%
# Display first 15 images of moles, and how they are classified
w=40
h=30
fig=plt.figure(figsize=(12, 8))
columns = 5
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if y_train[i] == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(X_train[i], interpolation='nearest')

plt.show()

# %%
plt.bar(0, y_train[np.where(y_train == 0)].shape[0], label = 'benign')
plt.bar(1, y_train[np.where(y_train == 1)].shape[0], label = 'malignant')
plt.legend()
plt.title("Training Data")
plt.show()

plt.bar(0, y_test[np.where(y_test == 0)].shape[0], label = 'benign')
plt.bar(1, y_test[np.where(y_test == 1)].shape[0], label = 'malignant')
plt.legend()
plt.title("Test Data")
plt.show()

# %%
## Normalize by dividing by RGB value
X_train = X_train/255
X_test = X_test/255

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()

# Input Layer
model.add(Conv2D(32,(3,3),activation='relu',input_shape = (224,224,3))) 
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# Bloack 1 
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# Block 2
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# Block 3
model.add(Conv2D(256,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# Fully Connected layers 
model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.2))

# Output layer
model.add(Dense(1,activation='sigmoid'))
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 222, 222, 32)      896
#
#  max_pooling2d_8 (MaxPooling  (None, 111, 111, 32)     0
#  2D)
#
#  dropout_10 (Dropout)        (None, 111, 111, 32)      0
#
#  conv2d_9 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_9 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  dropout_11 (Dropout)        (None, 54, 54, 64)        0
#
#  conv2d_10 (Conv2D)          (None, 52, 52, 128)       73856
#
#  max_pooling2d_10 (MaxPoolin  (None, 26, 26, 128)      0
#  g2D)
#
#  dropout_12 (Dropout)        (None, 26, 26, 128)       0
#
#  conv2d_11 (Conv2D)          (None, 24, 24, 256)       295168
#
#  max_pooling2d_11 (MaxPoolin  (None, 12, 12, 256)      0
#  g2D)
#
#  dropout_13 (Dropout)        (None, 12, 12, 256)       0
#
#  flatten_2 (Flatten)         (None, 36864)             0
#
#  dense_4 (Dense)             (None, 512)               18874880
#
#  dropout_14 (Dropout)        (None, 512)               0
#
#  dense_5 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 19,263,809
# Trainable params: 19,263,809
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ReduceLROnPlateau
learning_rate_annealer = ReduceLROnPlateau(monitor='val_acc',mode='max',
                                          patience=3,
                                          verbose=1,
                                          factor=0.5,
                                          min_lr = 1e-4)


history = model.fit(X_train,
                    y_train,
                    validation_split=0.2,
                    epochs=100,
                    batch_size = 64,
                    verbose=1,
                    callbacks=[learning_rate_annealer],validation_data=(X_test,y_test))



print(history.history.keys())
# Out:
# Epoch 1/100
# 21/21 [==============================] - ETA: 0s - loss: 1.3082 - accuracy: 0.4780WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 87s 3s/step - loss: 1.3082 - accuracy: 0.4780 - val_loss: 0.6922 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 2/100
# 21/21 [==============================] - ETA: 0s - loss: 0.6801 - accuracy: 0.5463WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 54s 3s/step - loss: 0.6801 - accuracy: 0.5463 - val_loss: 0.6583 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 3/100
# 21/21 [==============================] - ETA: 0s - loss: 0.6320 - accuracy: 0.6047WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.6320 - accuracy: 0.6047 - val_loss: 0.6717 - val_accuracy: 0.5970 - lr: 0.0010
# Epoch 4/100
# 21/21 [==============================] - ETA: 0s - loss: 0.6214 - accuracy: 0.6654WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.6214 - accuracy: 0.6654 - val_loss: 0.5940 - val_accuracy: 0.5939 - lr: 0.0010
# Epoch 5/100
# 21/21 [==============================] - ETA: 0s - loss: 0.5305 - accuracy: 0.7360WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.5305 - accuracy: 0.7360 - val_loss: 0.5549 - val_accuracy: 0.7455 - lr: 0.0010
# Epoch 6/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4729 - accuracy: 0.7716WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.4729 - accuracy: 0.7716 - val_loss: 0.5018 - val_accuracy: 0.7576 - lr: 0.0010
# Epoch 7/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4779 - accuracy: 0.7754WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 3s/step - loss: 0.4779 - accuracy: 0.7754 - val_loss: 0.5249 - val_accuracy: 0.7455 - lr: 0.0010
# Epoch 8/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4361 - accuracy: 0.7906WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 54s 3s/step - loss: 0.4361 - accuracy: 0.7906 - val_loss: 0.5362 - val_accuracy: 0.7000 - lr: 0.0010
# Epoch 9/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4708 - accuracy: 0.7769WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.4708 - accuracy: 0.7769 - val_loss: 0.4991 - val_accuracy: 0.7636 - lr: 0.0010
# Epoch 10/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4404 - accuracy: 0.7868WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.4404 - accuracy: 0.7868 - val_loss: 0.5018 - val_accuracy: 0.7939 - lr: 0.0010
# Epoch 11/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4199 - accuracy: 0.8005WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.4199 - accuracy: 0.8005 - val_loss: 0.4817 - val_accuracy: 0.7424 - lr: 0.0010
# Epoch 12/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4762 - accuracy: 0.7610WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.4762 - accuracy: 0.7610 - val_loss: 0.5018 - val_accuracy: 0.7485 - lr: 0.0010
# Epoch 13/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4385 - accuracy: 0.7860WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.4385 - accuracy: 0.7860 - val_loss: 0.4708 - val_accuracy: 0.7636 - lr: 0.0010
# Epoch 14/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4041 - accuracy: 0.8012WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.4041 - accuracy: 0.8012 - val_loss: 0.4676 - val_accuracy: 0.7667 - lr: 0.0010
# Epoch 15/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4080 - accuracy: 0.7959WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.4080 - accuracy: 0.7959 - val_loss: 0.4519 - val_accuracy: 0.7758 - lr: 0.0010
# Epoch 16/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3950 - accuracy: 0.8126WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.3950 - accuracy: 0.8126 - val_loss: 0.4590 - val_accuracy: 0.7576 - lr: 0.0010
# Epoch 17/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4055 - accuracy: 0.8035WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.4055 - accuracy: 0.8035 - val_loss: 0.4723 - val_accuracy: 0.7727 - lr: 0.0010
# Epoch 18/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3682 - accuracy: 0.8255WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.3682 - accuracy: 0.8255 - val_loss: 0.4415 - val_accuracy: 0.7818 - lr: 0.0010
# Epoch 19/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4015 - accuracy: 0.7936WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 54s 3s/step - loss: 0.4015 - accuracy: 0.7936 - val_loss: 0.4631 - val_accuracy: 0.7485 - lr: 0.0010
# Epoch 20/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4023 - accuracy: 0.7989WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.4023 - accuracy: 0.7989 - val_loss: 0.4478 - val_accuracy: 0.7545 - lr: 0.0010
# Epoch 21/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3839 - accuracy: 0.7989WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.3839 - accuracy: 0.7989 - val_loss: 0.4660 - val_accuracy: 0.7545 - lr: 0.0010
# Epoch 22/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3661 - accuracy: 0.8293WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.3661 - accuracy: 0.8293 - val_loss: 0.4576 - val_accuracy: 0.7727 - lr: 0.0010
# Epoch 23/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3700 - accuracy: 0.8149WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.3700 - accuracy: 0.8149 - val_loss: 0.4624 - val_accuracy: 0.7576 - lr: 0.0010
# Epoch 24/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3603 - accuracy: 0.8187WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.3603 - accuracy: 0.8187 - val_loss: 0.4270 - val_accuracy: 0.7758 - lr: 0.0010
# Epoch 25/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3621 - accuracy: 0.8308WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.3621 - accuracy: 0.8308 - val_loss: 0.4250 - val_accuracy: 0.7758 - lr: 0.0010
# Epoch 26/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3444 - accuracy: 0.8300WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.3444 - accuracy: 0.8300 - val_loss: 0.4507 - val_accuracy: 0.8091 - lr: 0.0010
# Epoch 27/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3153 - accuracy: 0.8589WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.3153 - accuracy: 0.8589 - val_loss: 0.4169 - val_accuracy: 0.8121 - lr: 0.0010
# Epoch 28/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3017 - accuracy: 0.8566WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.3017 - accuracy: 0.8566 - val_loss: 0.4407 - val_accuracy: 0.7758 - lr: 0.0010
# Epoch 29/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3169 - accuracy: 0.8483WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.3169 - accuracy: 0.8483 - val_loss: 0.4198 - val_accuracy: 0.7848 - lr: 0.0010
# Epoch 30/100
# 21/21 [==============================] - ETA: 0s - loss: 0.2957 - accuracy: 0.8642WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.2957 - accuracy: 0.8642 - val_loss: 0.4702 - val_accuracy: 0.7758 - lr: 0.0010
# Epoch 31/100
# 21/21 [==============================] - ETA: 0s - loss: 0.2826 - accuracy: 0.8665WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 54s 3s/step - loss: 0.2826 - accuracy: 0.8665 - val_loss: 0.4629 - val_accuracy: 0.8030 - lr: 0.0010
# Epoch 32/100
# 21/21 [==============================] - ETA: 0s - loss: 0.2899 - accuracy: 0.8687WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.2899 - accuracy: 0.8687 - val_loss: 0.4594 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 33/100
# 21/21 [==============================] - ETA: 0s - loss: 0.2874 - accuracy: 0.8551WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 54s 3s/step - loss: 0.2874 - accuracy: 0.8551 - val_loss: 0.4714 - val_accuracy: 0.7879 - lr: 0.0010
# Epoch 34/100
# 21/21 [==============================] - ETA: 0s - loss: 0.2614 - accuracy: 0.8801WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.2614 - accuracy: 0.8801 - val_loss: 0.5476 - val_accuracy: 0.7606 - lr: 0.0010
# Epoch 35/100
# 21/21 [==============================] - ETA: 0s - loss: 0.2735 - accuracy: 0.8604WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.2735 - accuracy: 0.8604 - val_loss: 0.5169 - val_accuracy: 0.7788 - lr: 0.0010
# Epoch 36/100
# 21/21 [==============================] - ETA: 0s - loss: 0.2621 - accuracy: 0.8847WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 60s 3s/step - loss: 0.2621 - accuracy: 0.8847 - val_loss: 0.5187 - val_accuracy: 0.7848 - lr: 0.0010
# Epoch 37/100
# 21/21 [==============================] - ETA: 0s - loss: 0.2545 - accuracy: 0.8832WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 54s 3s/step - loss: 0.2545 - accuracy: 0.8832 - val_loss: 0.5737 - val_accuracy: 0.7606 - lr: 0.0010
# Epoch 38/100
# 21/21 [==============================] - ETA: 0s - loss: 0.2370 - accuracy: 0.8923WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.2370 - accuracy: 0.8923 - val_loss: 0.5092 - val_accuracy: 0.7667 - lr: 0.0010
# Epoch 39/100
# 21/21 [==============================] - ETA: 0s - loss: 0.2412 - accuracy: 0.8885WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.2412 - accuracy: 0.8885 - val_loss: 0.5272 - val_accuracy: 0.7727 - lr: 0.0010
# Epoch 40/100
# 21/21 [==============================] - ETA: 0s - loss: 0.2247 - accuracy: 0.8983WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.2247 - accuracy: 0.8983 - val_loss: 0.5373 - val_accuracy: 0.7970 - lr: 0.0010
# Epoch 41/100
# 21/21 [==============================] - ETA: 0s - loss: 0.2084 - accuracy: 0.9036WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.2084 - accuracy: 0.9036 - val_loss: 0.5938 - val_accuracy: 0.7727 - lr: 0.0010
# Epoch 42/100
# 21/21 [==============================] - ETA: 0s - loss: 0.1970 - accuracy: 0.9105WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.1970 - accuracy: 0.9105 - val_loss: 0.5363 - val_accuracy: 0.7697 - lr: 0.0010
# Epoch 43/100
# 21/21 [==============================] - ETA: 0s - loss: 0.1758 - accuracy: 0.9188WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.1758 - accuracy: 0.9188 - val_loss: 0.6935 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 44/100
# 21/21 [==============================] - ETA: 0s - loss: 0.1561 - accuracy: 0.9317WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.1561 - accuracy: 0.9317 - val_loss: 0.6201 - val_accuracy: 0.8091 - lr: 0.0010
# Epoch 45/100
# 21/21 [==============================] - ETA: 0s - loss: 0.1859 - accuracy: 0.9127WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.1859 - accuracy: 0.9127 - val_loss: 0.7426 - val_accuracy: 0.7515 - lr: 0.0010
# Epoch 46/100
# 21/21 [==============================] - ETA: 0s - loss: 0.1856 - accuracy: 0.9203WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.1856 - accuracy: 0.9203 - val_loss: 0.8353 - val_accuracy: 0.7697 - lr: 0.0010
# Epoch 47/100
# 21/21 [==============================] - ETA: 0s - loss: 0.1392 - accuracy: 0.9385WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.1392 - accuracy: 0.9385 - val_loss: 0.7558 - val_accuracy: 0.7727 - lr: 0.0010
# Epoch 48/100
# 21/21 [==============================] - ETA: 0s - loss: 0.1386 - accuracy: 0.9408WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.1386 - accuracy: 0.9408 - val_loss: 0.8463 - val_accuracy: 0.7879 - lr: 0.0010
# Epoch 49/100
# 21/21 [==============================] - ETA: 0s - loss: 0.1367 - accuracy: 0.9492WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.1367 - accuracy: 0.9492 - val_loss: 0.6997 - val_accuracy: 0.7970 - lr: 0.0010
# Epoch 50/100
# 21/21 [==============================] - ETA: 0s - loss: 0.1187 - accuracy: 0.9522WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.1187 - accuracy: 0.9522 - val_loss: 0.9936 - val_accuracy: 0.7545 - lr: 0.0010
# Epoch 51/100
# 21/21 [==============================] - ETA: 0s - loss: 0.1263 - accuracy: 0.9484WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 54s 3s/step - loss: 0.1263 - accuracy: 0.9484 - val_loss: 0.7776 - val_accuracy: 0.7848 - lr: 0.0010
# Epoch 52/100
# 21/21 [==============================] - ETA: 0s - loss: 0.1193 - accuracy: 0.9552WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 57s 3s/step - loss: 0.1193 - accuracy: 0.9552 - val_loss: 0.8650 - val_accuracy: 0.7818 - lr: 0.0010
# Epoch 53/100
# 21/21 [==============================] - ETA: 0s - loss: 0.1001 - accuracy: 0.9560WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.1001 - accuracy: 0.9560 - val_loss: 0.7308 - val_accuracy: 0.7939 - lr: 0.0010
# Epoch 54/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0938 - accuracy: 0.9636WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.0938 - accuracy: 0.9636 - val_loss: 1.0167 - val_accuracy: 0.7667 - lr: 0.0010
# Epoch 55/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0640 - accuracy: 0.9772WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.0640 - accuracy: 0.9772 - val_loss: 0.9834 - val_accuracy: 0.7667 - lr: 0.0010
# Epoch 56/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0731 - accuracy: 0.9689WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.0731 - accuracy: 0.9689 - val_loss: 1.0867 - val_accuracy: 0.7667 - lr: 0.0010
# Epoch 57/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0704 - accuracy: 0.9757WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.0704 - accuracy: 0.9757 - val_loss: 1.0929 - val_accuracy: 0.7697 - lr: 0.0010
# Epoch 58/100
# 21/21 [==============================] - ETA: 0s - loss: 0.1345 - accuracy: 0.9492WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 54s 3s/step - loss: 0.1345 - accuracy: 0.9492 - val_loss: 0.7889 - val_accuracy: 0.7333 - lr: 0.0010
# Epoch 59/100
# 21/21 [==============================] - ETA: 0s - loss: 0.1134 - accuracy: 0.9636WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.1134 - accuracy: 0.9636 - val_loss: 1.1771 - val_accuracy: 0.7848 - lr: 0.0010
# Epoch 60/100
# 21/21 [==============================] - ETA: 0s - loss: 0.1546 - accuracy: 0.9514WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.1546 - accuracy: 0.9514 - val_loss: 0.8639 - val_accuracy: 0.7667 - lr: 0.0010
# Epoch 61/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0910 - accuracy: 0.9575WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.0910 - accuracy: 0.9575 - val_loss: 0.9588 - val_accuracy: 0.7909 - lr: 0.0010
# Epoch 62/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0568 - accuracy: 0.9818WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.0568 - accuracy: 0.9818 - val_loss: 1.2351 - val_accuracy: 0.7727 - lr: 0.0010
# Epoch 63/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0456 - accuracy: 0.9841WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 54s 3s/step - loss: 0.0456 - accuracy: 0.9841 - val_loss: 1.2752 - val_accuracy: 0.7848 - lr: 0.0010
# Epoch 64/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0531 - accuracy: 0.9810WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.0531 - accuracy: 0.9810 - val_loss: 1.3408 - val_accuracy: 0.7576 - lr: 0.0010
# Epoch 65/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0362 - accuracy: 0.9879WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 55s 3s/step - loss: 0.0362 - accuracy: 0.9879 - val_loss: 1.1568 - val_accuracy: 0.7727 - lr: 0.0010
# Epoch 66/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0461 - accuracy: 0.9856WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.0461 - accuracy: 0.9856 - val_loss: 1.4281 - val_accuracy: 0.7515 - lr: 0.0010
# Epoch 67/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0518 - accuracy: 0.9795WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.0518 - accuracy: 0.9795 - val_loss: 1.5514 - val_accuracy: 0.7545 - lr: 0.0010
# Epoch 68/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0670 - accuracy: 0.9719WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.0670 - accuracy: 0.9719 - val_loss: 1.0924 - val_accuracy: 0.7515 - lr: 0.0010
# Epoch 69/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0519 - accuracy: 0.9818WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.0519 - accuracy: 0.9818 - val_loss: 2.0608 - val_accuracy: 0.7455 - lr: 0.0010
# Epoch 70/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0622 - accuracy: 0.9795WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.0622 - accuracy: 0.9795 - val_loss: 1.8184 - val_accuracy: 0.7636 - lr: 0.0010
# Epoch 71/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0617 - accuracy: 0.9818WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.0617 - accuracy: 0.9818 - val_loss: 1.8257 - val_accuracy: 0.7788 - lr: 0.0010
# Epoch 72/100
# 21/21 [==============================] - ETA: 0s - loss: 0.1195 - accuracy: 0.9575WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.1195 - accuracy: 0.9575 - val_loss: 1.3534 - val_accuracy: 0.7788 - lr: 0.0010
# Epoch 73/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0645 - accuracy: 0.9742WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.0645 - accuracy: 0.9742 - val_loss: 1.4019 - val_accuracy: 0.7667 - lr: 0.0010
# Epoch 74/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0343 - accuracy: 0.9894WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.0343 - accuracy: 0.9894 - val_loss: 1.5394 - val_accuracy: 0.7576 - lr: 0.0010
# Epoch 75/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0211 - accuracy: 0.9932WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.0211 - accuracy: 0.9932 - val_loss: 1.3747 - val_accuracy: 0.7636 - lr: 0.0010
# Epoch 76/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.9954WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.0143 - accuracy: 0.9954 - val_loss: 1.6236 - val_accuracy: 0.7697 - lr: 0.0010
# Epoch 77/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.9947WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.0154 - accuracy: 0.9947 - val_loss: 1.5398 - val_accuracy: 0.7788 - lr: 0.0010
# Epoch 78/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9970WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.0134 - accuracy: 0.9970 - val_loss: 1.7275 - val_accuracy: 0.7727 - lr: 0.0010
# Epoch 79/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0479 - accuracy: 0.9803WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 54s 3s/step - loss: 0.0479 - accuracy: 0.9803 - val_loss: 1.7027 - val_accuracy: 0.7636 - lr: 0.0010
# Epoch 80/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0434 - accuracy: 0.9879WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.0434 - accuracy: 0.9879 - val_loss: 1.3890 - val_accuracy: 0.7727 - lr: 0.0010
# Epoch 81/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0626 - accuracy: 0.9734WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.0626 - accuracy: 0.9734 - val_loss: 1.5749 - val_accuracy: 0.7758 - lr: 0.0010
# Epoch 82/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0353 - accuracy: 0.9909WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 54s 3s/step - loss: 0.0353 - accuracy: 0.9909 - val_loss: 1.5563 - val_accuracy: 0.7939 - lr: 0.0010
# Epoch 83/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0155 - accuracy: 0.9962WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 54s 3s/step - loss: 0.0155 - accuracy: 0.9962 - val_loss: 1.4850 - val_accuracy: 0.7788 - lr: 0.0010
# Epoch 84/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0172 - accuracy: 0.9954WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 54s 3s/step - loss: 0.0172 - accuracy: 0.9954 - val_loss: 1.7667 - val_accuracy: 0.7545 - lr: 0.0010
# Epoch 85/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0336 - accuracy: 0.9894WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 54s 3s/step - loss: 0.0336 - accuracy: 0.9894 - val_loss: 1.6429 - val_accuracy: 0.7606 - lr: 0.0010
# Epoch 86/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0380 - accuracy: 0.9856WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.0380 - accuracy: 0.9856 - val_loss: 1.5516 - val_accuracy: 0.7848 - lr: 0.0010
# Epoch 87/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0105 - accuracy: 0.9977WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.0105 - accuracy: 0.9977 - val_loss: 1.7989 - val_accuracy: 0.7909 - lr: 0.0010
# Epoch 88/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9954WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.0147 - accuracy: 0.9954 - val_loss: 1.6509 - val_accuracy: 0.8061 - lr: 0.0010
# Epoch 89/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 0.9954WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 56s 3s/step - loss: 0.0194 - accuracy: 0.9954 - val_loss: 1.4960 - val_accuracy: 0.7788 - lr: 0.0010
# Epoch 90/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.9924WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 54s 3s/step - loss: 0.0237 - accuracy: 0.9924 - val_loss: 1.6355 - val_accuracy: 0.7909 - lr: 0.0010
# Epoch 91/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.9954WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.0143 - accuracy: 0.9954 - val_loss: 1.5030 - val_accuracy: 0.7939 - lr: 0.0010
# Epoch 92/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9977WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 59s 3s/step - loss: 0.0084 - accuracy: 0.9977 - val_loss: 1.5711 - val_accuracy: 0.7727 - lr: 0.0010
# Epoch 93/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9977WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 65s 3s/step - loss: 0.0080 - accuracy: 0.9977 - val_loss: 2.1358 - val_accuracy: 0.7727 - lr: 0.0010
# Epoch 94/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9985WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 54s 3s/step - loss: 0.0051 - accuracy: 0.9985 - val_loss: 1.6764 - val_accuracy: 0.7879 - lr: 0.0010
# Epoch 95/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9977WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 57s 3s/step - loss: 0.0080 - accuracy: 0.9977 - val_loss: 1.9309 - val_accuracy: 0.7788 - lr: 0.0010
# Epoch 96/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9909WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.0255 - accuracy: 0.9909 - val_loss: 1.9305 - val_accuracy: 0.7606 - lr: 0.0010
# Epoch 97/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0362 - accuracy: 0.9894WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.0362 - accuracy: 0.9894 - val_loss: 1.7665 - val_accuracy: 0.7576 - lr: 0.0010
# Epoch 98/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0387 - accuracy: 0.9901WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.0387 - accuracy: 0.9901 - val_loss: 1.7588 - val_accuracy: 0.7455 - lr: 0.0010
# Epoch 99/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0432 - accuracy: 0.9886WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 3s/step - loss: 0.0432 - accuracy: 0.9886 - val_loss: 1.3651 - val_accuracy: 0.7788 - lr: 0.0010
# Epoch 100/100
# 21/21 [==============================] - ETA: 0s - loss: 0.1265 - accuracy: 0.9643WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 53s 3s/step - loss: 0.1265 - accuracy: 0.9643 - val_loss: 1.4659 - val_accuracy: 0.7212 - lr: 0.0010
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')

plt.legend(['Train', 'Val'], loc='upper left')
plt.show()


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')

plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
