# %% [markdown]
# <a href="https://colab.research.google.com/github/dangalmar/TFG_Imagenes_Medicas/blob/main/Tratamiento_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler

import os

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from glob import glob
import seaborn as sns
from PIL import Image

# %%
folder_benign_train = '../../new_data/train/benign'
folder_malignant_train = '../../new_data/train/malignant'

folder_benign_test = '../../new_data/test/benign'
folder_malignant_test = '../../new_data/test/malignant'

read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))

# Load in training pictures
ims_benign = [read(os.path.join(folder_benign_train, filename)) for filename in os.listdir(folder_benign_train)]
X_benign = np.array(ims_benign, dtype='uint8')
ims_malignant = [read(os.path.join(folder_malignant_train, filename)) for filename in os.listdir(folder_malignant_train)]
X_malignant = np.array(ims_malignant, dtype='uint8')

# Load in testing pictures
ims_benign = [read(os.path.join(folder_benign_test, filename)) for filename in os.listdir(folder_benign_test)]
X_benign_test = np.array(ims_benign, dtype='uint8')
ims_malignant = [read(os.path.join(folder_malignant_test, filename)) for filename in os.listdir(folder_malignant_test)]
X_malignant_test = np.array(ims_malignant, dtype='uint8')

# Create labels
y_benign = np.zeros(X_benign.shape[0])
y_malignant = np.ones(X_malignant.shape[0])

y_benign_test = np.zeros(X_benign_test.shape[0])
y_malignant_test = np.ones(X_malignant_test.shape[0])


# Merge data
X_train = np.concatenate((X_benign, X_malignant), axis = 0)
y_train = np.concatenate((y_benign, y_malignant), axis = 0)

X_test = np.concatenate((X_benign_test, X_malignant_test), axis = 0)
y_test = np.concatenate((y_benign_test, y_malignant_test), axis = 0)

# Shuffle data
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
y_train = y_train[s]

s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
y_test = y_test[s]

# %%
# Display first 15 images of moles, and how they are classified
w=40
h=30
fig=plt.figure(figsize=(12, 8))
columns = 5
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if y_train[i] == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(X_train[i], interpolation='nearest')

plt.show()

# %%
plt.bar(0, y_train[np.where(y_train == 0)].shape[0], label = 'benign')
plt.bar(1, y_train[np.where(y_train == 1)].shape[0], label = 'malignant')
plt.legend()
plt.title("Training Data")
plt.show()

plt.bar(0, y_test[np.where(y_test == 0)].shape[0], label = 'benign')
plt.bar(1, y_test[np.where(y_test == 1)].shape[0], label = 'malignant')
plt.legend()
plt.title("Test Data")
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

# %%
from keras.preprocessing.image import ImageDataGenerator

# Crear un generador de aumento de datos para las imágenes de entrenamiento
train_datagen = ImageDataGenerator(
    rescale=1./255,             # Normalizar los valores de píxeles
    rotation_range=40,          # Rango de rotación aleatorio
    width_shift_range=0.2,      # Desplazamiento horizontal aleatorio
    height_shift_range=0.2,     # Desplazamiento vertical aleatorio
    shear_range=0.2,            # Distorsión de cizalla aleatoria
    zoom_range=0.2,             # Zoom aleatorio
    horizontal_flip=True,       # Volteo horizontal aleatorio
    fill_mode='nearest'         # Modo de relleno para los píxeles que faltan después de la transformación
)

# Crear un generador de aumento de datos para las imágenes de validación (solo normalización)
validation_datagen = ImageDataGenerator(rescale=1./255)

# Configurar los generadores de flujo de datos
train_generator = train_datagen.flow(
    X_train, y_train,           # Datos de entrenamiento
    batch_size=32              # Tamaño del lote
)

validation_generator = validation_datagen.flow(
    X_test, y_test,             # Datos de validación
    batch_size=32
)

# %%
model = Sequential()

# Input Layer
model.add(Conv2D(32,(3,3),activation='relu',input_shape = (224,224,3))) 
model.add(MaxPooling2D(pool_size=(2,2)))

# Bloack 1 
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# Block 2
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# Block 3
model.add(Conv2D(256,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# Fully Connected layers 
model.add(Flatten())
model.add(Dense(512,activation='relu'))

# Output layer
model.add(Dense(1,activation='sigmoid'))
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 222, 222, 32)      896
#
#  max_pooling2d_12 (MaxPoolin  (None, 111, 111, 32)     0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 109, 109, 64)      18496
#
#  max_pooling2d_13 (MaxPoolin  (None, 54, 54, 64)       0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 52, 52, 128)       73856
#
#  max_pooling2d_14 (MaxPoolin  (None, 26, 26, 128)      0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 24, 24, 256)       295168
#
#  max_pooling2d_15 (MaxPoolin  (None, 12, 12, 256)      0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 36864)             0
#
#  dense_6 (Dense)             (None, 512)               18874880
#
#  dense_7 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 19,263,809
# Trainable params: 19,263,809
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ReduceLROnPlateau
learning_rate_annealer = ReduceLROnPlateau(monitor='val_acc',mode='max',
                                          patience=3,
                                          verbose=1,
                                          factor=0.5,
                                          min_lr = 1e-4)


history = model.fit(train_generator,
                    steps_per_epoch=len(X_train) // 32,
                    validation_split=0.2,
                    epochs=100,
                    batch_size = 64,
                    verbose=1,
                    callbacks=[learning_rate_annealer],
                    validation_data=validation_generator,
                    validation_steps=len(X_test) // 32 )



print(history.history.keys())
# Out:
# Epoch 1/100
# 41/41 [==============================] - ETA: 0s - loss: 0.8121 - accuracy: 0.5591WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.8121 - accuracy: 0.5591 - val_loss: 0.5913 - val_accuracy: 0.6656 - lr: 0.0010
# Epoch 2/100
# 41/41 [==============================] - ETA: 0s - loss: 0.6170 - accuracy: 0.7068WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 52s 1s/step - loss: 0.6170 - accuracy: 0.7068 - val_loss: 0.6367 - val_accuracy: 0.7375 - lr: 0.0010
# Epoch 3/100
# 41/41 [==============================] - ETA: 0s - loss: 0.5411 - accuracy: 0.7294WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 52s 1s/step - loss: 0.5411 - accuracy: 0.7294 - val_loss: 0.5234 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 4/100
# 41/41 [==============================] - ETA: 0s - loss: 0.5454 - accuracy: 0.7341WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.5454 - accuracy: 0.7341 - val_loss: 0.5644 - val_accuracy: 0.6375 - lr: 0.0010
# Epoch 5/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4895 - accuracy: 0.7691WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 52s 1s/step - loss: 0.4895 - accuracy: 0.7691 - val_loss: 0.4947 - val_accuracy: 0.7563 - lr: 0.0010
# Epoch 6/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4847 - accuracy: 0.7644WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 51s 1s/step - loss: 0.4847 - accuracy: 0.7644 - val_loss: 0.4786 - val_accuracy: 0.7406 - lr: 0.0010
# Epoch 7/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4520 - accuracy: 0.7846WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 57s 1s/step - loss: 0.4520 - accuracy: 0.7846 - val_loss: 0.4615 - val_accuracy: 0.7594 - lr: 0.0010
# Epoch 8/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4421 - accuracy: 0.7799WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 57s 1s/step - loss: 0.4421 - accuracy: 0.7799 - val_loss: 0.4925 - val_accuracy: 0.7531 - lr: 0.0010
# Epoch 9/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4487 - accuracy: 0.7862WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 51s 1s/step - loss: 0.4487 - accuracy: 0.7862 - val_loss: 0.5711 - val_accuracy: 0.6750 - lr: 0.0010
# Epoch 10/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4860 - accuracy: 0.7652WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.4860 - accuracy: 0.7652 - val_loss: 0.4532 - val_accuracy: 0.7531 - lr: 0.0010
# Epoch 11/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4148 - accuracy: 0.8017WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.4148 - accuracy: 0.8017 - val_loss: 0.4403 - val_accuracy: 0.7781 - lr: 0.0010
# Epoch 12/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4255 - accuracy: 0.7970WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.4255 - accuracy: 0.7970 - val_loss: 0.4681 - val_accuracy: 0.7531 - lr: 0.0010
# Epoch 13/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4675 - accuracy: 0.7504WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.4675 - accuracy: 0.7504 - val_loss: 0.4746 - val_accuracy: 0.7719 - lr: 0.0010
# Epoch 14/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4558 - accuracy: 0.7955WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.4558 - accuracy: 0.7955 - val_loss: 0.5310 - val_accuracy: 0.7250 - lr: 0.0010
# Epoch 15/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4270 - accuracy: 0.7900WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 51s 1s/step - loss: 0.4270 - accuracy: 0.7900 - val_loss: 0.4901 - val_accuracy: 0.7375 - lr: 0.0010
# Epoch 16/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4453 - accuracy: 0.7924WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 52s 1s/step - loss: 0.4453 - accuracy: 0.7924 - val_loss: 0.4634 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 17/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4175 - accuracy: 0.7978WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 52s 1s/step - loss: 0.4175 - accuracy: 0.7978 - val_loss: 0.4705 - val_accuracy: 0.7250 - lr: 0.0010
# Epoch 18/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4456 - accuracy: 0.7978WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.4456 - accuracy: 0.7978 - val_loss: 0.4338 - val_accuracy: 0.7563 - lr: 0.0010
# Epoch 19/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4052 - accuracy: 0.7978WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.4052 - accuracy: 0.7978 - val_loss: 0.4976 - val_accuracy: 0.7625 - lr: 0.0010
# Epoch 20/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4002 - accuracy: 0.8002WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 52s 1s/step - loss: 0.4002 - accuracy: 0.8002 - val_loss: 0.4206 - val_accuracy: 0.7750 - lr: 0.0010
# Epoch 21/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4021 - accuracy: 0.8079WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.4021 - accuracy: 0.8079 - val_loss: 0.4398 - val_accuracy: 0.7656 - lr: 0.0010
# Epoch 22/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3907 - accuracy: 0.8118WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 52s 1s/step - loss: 0.3907 - accuracy: 0.8118 - val_loss: 0.4365 - val_accuracy: 0.7719 - lr: 0.0010
# Epoch 23/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3996 - accuracy: 0.8118WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 54s 1s/step - loss: 0.3996 - accuracy: 0.8118 - val_loss: 0.4345 - val_accuracy: 0.7719 - lr: 0.0010
# Epoch 24/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4227 - accuracy: 0.7955WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 51s 1s/step - loss: 0.4227 - accuracy: 0.7955 - val_loss: 0.4162 - val_accuracy: 0.7812 - lr: 0.0010
# Epoch 25/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3944 - accuracy: 0.8118WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 51s 1s/step - loss: 0.3944 - accuracy: 0.8118 - val_loss: 0.4836 - val_accuracy: 0.7750 - lr: 0.0010
# Epoch 26/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4024 - accuracy: 0.8072WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 51s 1s/step - loss: 0.4024 - accuracy: 0.8072 - val_loss: 0.4259 - val_accuracy: 0.7781 - lr: 0.0010
# Epoch 27/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4216 - accuracy: 0.7947WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 51s 1s/step - loss: 0.4216 - accuracy: 0.7947 - val_loss: 0.4180 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 28/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4244 - accuracy: 0.7869WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.4244 - accuracy: 0.7869 - val_loss: 0.4065 - val_accuracy: 0.7781 - lr: 0.0010
# Epoch 29/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3858 - accuracy: 0.8157WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 54s 1s/step - loss: 0.3858 - accuracy: 0.8157 - val_loss: 0.4070 - val_accuracy: 0.7906 - lr: 0.0010
# Epoch 30/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4042 - accuracy: 0.8056WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 51s 1s/step - loss: 0.4042 - accuracy: 0.8056 - val_loss: 0.4110 - val_accuracy: 0.7906 - lr: 0.0010
# Epoch 31/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3968 - accuracy: 0.8095WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 69s 2s/step - loss: 0.3968 - accuracy: 0.8095 - val_loss: 0.4158 - val_accuracy: 0.7937 - lr: 0.0010
# Epoch 32/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3866 - accuracy: 0.8142WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 57s 1s/step - loss: 0.3866 - accuracy: 0.8142 - val_loss: 0.4674 - val_accuracy: 0.7688 - lr: 0.0010
# Epoch 33/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4569 - accuracy: 0.7924WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 57s 1s/step - loss: 0.4569 - accuracy: 0.7924 - val_loss: 0.4409 - val_accuracy: 0.7906 - lr: 0.0010
# Epoch 34/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4490 - accuracy: 0.7908WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 55s 1s/step - loss: 0.4490 - accuracy: 0.7908 - val_loss: 0.5102 - val_accuracy: 0.7469 - lr: 0.0010
# Epoch 35/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4161 - accuracy: 0.8009WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 51s 1s/step - loss: 0.4161 - accuracy: 0.8009 - val_loss: 0.4193 - val_accuracy: 0.7969 - lr: 0.0010
# Epoch 36/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4145 - accuracy: 0.8040WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 52s 1s/step - loss: 0.4145 - accuracy: 0.8040 - val_loss: 0.4180 - val_accuracy: 0.7750 - lr: 0.0010
# Epoch 37/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3941 - accuracy: 0.8140WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 54s 1s/step - loss: 0.3941 - accuracy: 0.8140 - val_loss: 0.4205 - val_accuracy: 0.7844 - lr: 0.0010
# Epoch 38/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3850 - accuracy: 0.8142WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 54s 1s/step - loss: 0.3850 - accuracy: 0.8142 - val_loss: 0.4403 - val_accuracy: 0.7594 - lr: 0.0010
# Epoch 39/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3785 - accuracy: 0.8095WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.3785 - accuracy: 0.8095 - val_loss: 0.4127 - val_accuracy: 0.7937 - lr: 0.0010
# Epoch 40/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3920 - accuracy: 0.8103WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 52s 1s/step - loss: 0.3920 - accuracy: 0.8103 - val_loss: 0.4353 - val_accuracy: 0.7937 - lr: 0.0010
# Epoch 41/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4151 - accuracy: 0.8040WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 54s 1s/step - loss: 0.4151 - accuracy: 0.8040 - val_loss: 0.4345 - val_accuracy: 0.7750 - lr: 0.0010
# Epoch 42/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3815 - accuracy: 0.8103WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 52s 1s/step - loss: 0.3815 - accuracy: 0.8103 - val_loss: 0.3901 - val_accuracy: 0.8156 - lr: 0.0010
# Epoch 43/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3892 - accuracy: 0.8126WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.3892 - accuracy: 0.8126 - val_loss: 0.4354 - val_accuracy: 0.7969 - lr: 0.0010
# Epoch 44/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3873 - accuracy: 0.8079WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 51s 1s/step - loss: 0.3873 - accuracy: 0.8079 - val_loss: 0.4237 - val_accuracy: 0.7937 - lr: 0.0010
# Epoch 45/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3945 - accuracy: 0.8079WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 54s 1s/step - loss: 0.3945 - accuracy: 0.8079 - val_loss: 0.4191 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 46/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3637 - accuracy: 0.8266WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 55s 1s/step - loss: 0.3637 - accuracy: 0.8266 - val_loss: 0.4084 - val_accuracy: 0.7844 - lr: 0.0010
# Epoch 47/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3880 - accuracy: 0.8149WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.3880 - accuracy: 0.8149 - val_loss: 0.3916 - val_accuracy: 0.8156 - lr: 0.0010
# Epoch 48/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3702 - accuracy: 0.8212WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.3702 - accuracy: 0.8212 - val_loss: 0.4378 - val_accuracy: 0.7719 - lr: 0.0010
# Epoch 49/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3841 - accuracy: 0.8235WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.3841 - accuracy: 0.8235 - val_loss: 0.4113 - val_accuracy: 0.7875 - lr: 0.0010
# Epoch 50/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3654 - accuracy: 0.8149WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 55s 1s/step - loss: 0.3654 - accuracy: 0.8149 - val_loss: 0.3956 - val_accuracy: 0.7875 - lr: 0.0010
# Epoch 51/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3895 - accuracy: 0.8056WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.3895 - accuracy: 0.8056 - val_loss: 0.3942 - val_accuracy: 0.7844 - lr: 0.0010
# Epoch 52/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3787 - accuracy: 0.8087WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 55s 1s/step - loss: 0.3787 - accuracy: 0.8087 - val_loss: 0.4052 - val_accuracy: 0.7844 - lr: 0.0010
# Epoch 53/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3869 - accuracy: 0.8087WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 55s 1s/step - loss: 0.3869 - accuracy: 0.8087 - val_loss: 0.4054 - val_accuracy: 0.7812 - lr: 0.0010
# Epoch 54/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3661 - accuracy: 0.8134WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 57s 1s/step - loss: 0.3661 - accuracy: 0.8134 - val_loss: 0.4215 - val_accuracy: 0.7750 - lr: 0.0010
# Epoch 55/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3622 - accuracy: 0.8250WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 62s 2s/step - loss: 0.3622 - accuracy: 0.8250 - val_loss: 0.4013 - val_accuracy: 0.7844 - lr: 0.0010
# Epoch 56/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3764 - accuracy: 0.8250WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 56s 1s/step - loss: 0.3764 - accuracy: 0.8250 - val_loss: 0.4084 - val_accuracy: 0.7875 - lr: 0.0010
# Epoch 57/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3890 - accuracy: 0.8281WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 55s 1s/step - loss: 0.3890 - accuracy: 0.8281 - val_loss: 0.4019 - val_accuracy: 0.7656 - lr: 0.0010
# Epoch 58/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3887 - accuracy: 0.8079WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 56s 1s/step - loss: 0.3887 - accuracy: 0.8079 - val_loss: 0.4292 - val_accuracy: 0.7781 - lr: 0.0010
# Epoch 59/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3708 - accuracy: 0.8212WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 65s 2s/step - loss: 0.3708 - accuracy: 0.8212 - val_loss: 0.4451 - val_accuracy: 0.7875 - lr: 0.0010
# Epoch 60/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3761 - accuracy: 0.8110WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 65s 2s/step - loss: 0.3761 - accuracy: 0.8110 - val_loss: 0.3839 - val_accuracy: 0.8062 - lr: 0.0010
# Epoch 61/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3443 - accuracy: 0.8266WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 65s 2s/step - loss: 0.3443 - accuracy: 0.8266 - val_loss: 0.4225 - val_accuracy: 0.8188 - lr: 0.0010
# Epoch 62/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3533 - accuracy: 0.8414WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 65s 2s/step - loss: 0.3533 - accuracy: 0.8414 - val_loss: 0.4557 - val_accuracy: 0.8188 - lr: 0.0010
# Epoch 63/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3644 - accuracy: 0.8289WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 65s 2s/step - loss: 0.3644 - accuracy: 0.8289 - val_loss: 0.4167 - val_accuracy: 0.8062 - lr: 0.0010
# Epoch 64/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3502 - accuracy: 0.8281WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 66s 2s/step - loss: 0.3502 - accuracy: 0.8281 - val_loss: 0.4007 - val_accuracy: 0.8031 - lr: 0.0010
# Epoch 65/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3720 - accuracy: 0.8126WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 64s 2s/step - loss: 0.3720 - accuracy: 0.8126 - val_loss: 0.3914 - val_accuracy: 0.8062 - lr: 0.0010
# Epoch 66/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3817 - accuracy: 0.8180WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 65s 2s/step - loss: 0.3817 - accuracy: 0.8180 - val_loss: 0.5144 - val_accuracy: 0.7531 - lr: 0.0010
# Epoch 67/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3666 - accuracy: 0.8281WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 65s 2s/step - loss: 0.3666 - accuracy: 0.8281 - val_loss: 0.3857 - val_accuracy: 0.8156 - lr: 0.0010
# Epoch 68/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3446 - accuracy: 0.8375WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 64s 2s/step - loss: 0.3446 - accuracy: 0.8375 - val_loss: 0.3944 - val_accuracy: 0.8062 - lr: 0.0010
# Epoch 69/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3469 - accuracy: 0.8383WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 65s 2s/step - loss: 0.3469 - accuracy: 0.8383 - val_loss: 0.3956 - val_accuracy: 0.7875 - lr: 0.0010
# Epoch 70/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3583 - accuracy: 0.8235WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 64s 2s/step - loss: 0.3583 - accuracy: 0.8235 - val_loss: 0.4020 - val_accuracy: 0.7875 - lr: 0.0010
# Epoch 71/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3438 - accuracy: 0.8281WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 63s 2s/step - loss: 0.3438 - accuracy: 0.8281 - val_loss: 0.4521 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 72/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3921 - accuracy: 0.8250WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 64s 2s/step - loss: 0.3921 - accuracy: 0.8250 - val_loss: 0.4674 - val_accuracy: 0.7563 - lr: 0.0010
# Epoch 73/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3804 - accuracy: 0.8227WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 65s 2s/step - loss: 0.3804 - accuracy: 0.8227 - val_loss: 0.3895 - val_accuracy: 0.8062 - lr: 0.0010
# Epoch 74/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3518 - accuracy: 0.8390WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 65s 2s/step - loss: 0.3518 - accuracy: 0.8390 - val_loss: 0.3937 - val_accuracy: 0.7969 - lr: 0.0010
# Epoch 75/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3639 - accuracy: 0.8297WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 67s 2s/step - loss: 0.3639 - accuracy: 0.8297 - val_loss: 0.3811 - val_accuracy: 0.8125 - lr: 0.0010
# Epoch 76/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3311 - accuracy: 0.8453WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.3311 - accuracy: 0.8453 - val_loss: 0.3703 - val_accuracy: 0.8250 - lr: 0.0010
# Epoch 77/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3684 - accuracy: 0.8313WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 52s 1s/step - loss: 0.3684 - accuracy: 0.8313 - val_loss: 0.3737 - val_accuracy: 0.8344 - lr: 0.0010
# Epoch 78/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3347 - accuracy: 0.8351WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.3347 - accuracy: 0.8351 - val_loss: 0.3636 - val_accuracy: 0.8094 - lr: 0.0010
# Epoch 79/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3657 - accuracy: 0.8180WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.3657 - accuracy: 0.8180 - val_loss: 0.4117 - val_accuracy: 0.7906 - lr: 0.0010
# Epoch 80/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3514 - accuracy: 0.8173WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.3514 - accuracy: 0.8173 - val_loss: 0.4181 - val_accuracy: 0.7906 - lr: 0.0010
# Epoch 81/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3241 - accuracy: 0.8445WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.3241 - accuracy: 0.8445 - val_loss: 0.4256 - val_accuracy: 0.7969 - lr: 0.0010
# Epoch 82/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3475 - accuracy: 0.8359WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 54s 1s/step - loss: 0.3475 - accuracy: 0.8359 - val_loss: 0.3970 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 83/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3447 - accuracy: 0.8173WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 57s 1s/step - loss: 0.3447 - accuracy: 0.8173 - val_loss: 0.4070 - val_accuracy: 0.7937 - lr: 0.0010
# Epoch 84/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3440 - accuracy: 0.8320WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 55s 1s/step - loss: 0.3440 - accuracy: 0.8320 - val_loss: 0.3945 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 85/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3232 - accuracy: 0.8491WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.3232 - accuracy: 0.8491 - val_loss: 0.3717 - val_accuracy: 0.8031 - lr: 0.0010
# Epoch 86/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3355 - accuracy: 0.8367WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 62s 1s/step - loss: 0.3355 - accuracy: 0.8367 - val_loss: 0.4060 - val_accuracy: 0.8062 - lr: 0.0010
# Epoch 87/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3400 - accuracy: 0.8320WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.3400 - accuracy: 0.8320 - val_loss: 0.4033 - val_accuracy: 0.8156 - lr: 0.0010
# Epoch 88/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3367 - accuracy: 0.8250WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 54s 1s/step - loss: 0.3367 - accuracy: 0.8250 - val_loss: 0.4015 - val_accuracy: 0.7969 - lr: 0.0010
# Epoch 89/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3405 - accuracy: 0.8289WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.3405 - accuracy: 0.8289 - val_loss: 0.4047 - val_accuracy: 0.8094 - lr: 0.0010
# Epoch 90/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3363 - accuracy: 0.8328WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.3363 - accuracy: 0.8328 - val_loss: 0.4370 - val_accuracy: 0.8094 - lr: 0.0010
# Epoch 91/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3324 - accuracy: 0.8445WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 54s 1s/step - loss: 0.3324 - accuracy: 0.8445 - val_loss: 0.3975 - val_accuracy: 0.7812 - lr: 0.0010
# Epoch 92/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3233 - accuracy: 0.8499WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.3233 - accuracy: 0.8499 - val_loss: 0.3785 - val_accuracy: 0.7906 - lr: 0.0010
# Epoch 93/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3289 - accuracy: 0.8484WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.3289 - accuracy: 0.8484 - val_loss: 0.3907 - val_accuracy: 0.8062 - lr: 0.0010
# Epoch 94/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3372 - accuracy: 0.8491WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.3372 - accuracy: 0.8491 - val_loss: 0.4064 - val_accuracy: 0.8031 - lr: 0.0010
# Epoch 95/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3242 - accuracy: 0.8460WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.3242 - accuracy: 0.8460 - val_loss: 0.3844 - val_accuracy: 0.8250 - lr: 0.0010
# Epoch 96/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3377 - accuracy: 0.8484WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.3377 - accuracy: 0.8484 - val_loss: 0.3942 - val_accuracy: 0.7969 - lr: 0.0010
# Epoch 97/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3399 - accuracy: 0.8414WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.3399 - accuracy: 0.8414 - val_loss: 0.3687 - val_accuracy: 0.8344 - lr: 0.0010
# Epoch 98/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3314 - accuracy: 0.8351WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 54s 1s/step - loss: 0.3314 - accuracy: 0.8351 - val_loss: 0.3672 - val_accuracy: 0.8250 - lr: 0.0010
# Epoch 99/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3283 - accuracy: 0.8367WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 53s 1s/step - loss: 0.3283 - accuracy: 0.8367 - val_loss: 0.3599 - val_accuracy: 0.8219 - lr: 0.0010
# Epoch 100/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3113 - accuracy: 0.8639WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 41/41 [==============================] - 52s 1s/step - loss: 0.3113 - accuracy: 0.8639 - val_loss: 0.3765 - val_accuracy: 0.8094 - lr: 0.0010
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')

plt.legend(['Train', 'Val'], loc='upper left')
plt.show()


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')

plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
