# %% [markdown]
# <a href="https://colab.research.google.com/github/dangalmar/TFG_Imagenes_Medicas/blob/main/Tratamiento_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler

import os

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from glob import glob
import seaborn as sns
from PIL import Image

# %%
folder_benign_train = '../../new_data/train/benign'
folder_malignant_train = '../../new_data/train/malignant'

folder_benign_test = '../../new_data/test/benign'
folder_malignant_test = '../../new_data/test/malignant'

read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))

# Load in training pictures
ims_benign = [read(os.path.join(folder_benign_train, filename)) for filename in os.listdir(folder_benign_train)]
X_benign = np.array(ims_benign, dtype='uint8')
ims_malignant = [read(os.path.join(folder_malignant_train, filename)) for filename in os.listdir(folder_malignant_train)]
X_malignant = np.array(ims_malignant, dtype='uint8')

# Load in testing pictures
ims_benign = [read(os.path.join(folder_benign_test, filename)) for filename in os.listdir(folder_benign_test)]
X_benign_test = np.array(ims_benign, dtype='uint8')
ims_malignant = [read(os.path.join(folder_malignant_test, filename)) for filename in os.listdir(folder_malignant_test)]
X_malignant_test = np.array(ims_malignant, dtype='uint8')

# Create labels
y_benign = np.zeros(X_benign.shape[0])
y_malignant = np.ones(X_malignant.shape[0])

y_benign_test = np.zeros(X_benign_test.shape[0])
y_malignant_test = np.ones(X_malignant_test.shape[0])


# Merge data
X_train = np.concatenate((X_benign, X_malignant), axis = 0)
y_train = np.concatenate((y_benign, y_malignant), axis = 0)

X_test = np.concatenate((X_benign_test, X_malignant_test), axis = 0)
y_test = np.concatenate((y_benign_test, y_malignant_test), axis = 0)

# Shuffle data
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
y_train = y_train[s]

s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
y_test = y_test[s]

# %%
# Display first 15 images of moles, and how they are classified
w=40
h=30
fig=plt.figure(figsize=(12, 8))
columns = 5
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if y_train[i] == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(X_train[i], interpolation='nearest')

plt.show()

# %%
plt.bar(0, y_train[np.where(y_train == 0)].shape[0], label = 'benign')
plt.bar(1, y_train[np.where(y_train == 1)].shape[0], label = 'malignant')
plt.legend()
plt.title("Training Data")
plt.show()

plt.bar(0, y_test[np.where(y_test == 0)].shape[0], label = 'benign')
plt.bar(1, y_test[np.where(y_test == 1)].shape[0], label = 'malignant')
plt.legend()
plt.title("Test Data")
plt.show()

# %%
## Normalize by dividing by RGB value
X_train = X_train/255
X_test = X_test/255

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import RMSprop

# %%
model = Sequential()

# Input Layer
model.add(Conv2D(32,(3,3),activation='relu',input_shape = (224,224,3))) 
model.add(MaxPooling2D(pool_size=(2,2)))

# Bloack 1 
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# Block 2
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# Block 3
model.add(Conv2D(256,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# Fully Connected layers 
model.add(Flatten())
model.add(Dense(512,activation='relu'))

# Output layer
model.add(Dense(1,activation='sigmoid'))
optimizer = RMSprop(learning_rate=0.001)
model.compile(optimizer=optimizer,loss='binary_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 256)      0
#  2D)
#
#  flatten (Flatten)           (None, 36864)             0
#
#  dense (Dense)               (None, 512)               18874880
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 19,263,809
# Trainable params: 19,263,809
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ReduceLROnPlateau
learning_rate_annealer = ReduceLROnPlateau(monitor='val_acc',mode='max',
                                          patience=3,
                                          verbose=1,
                                          factor=0.5,
                                          min_lr = 1e-4)


history = model.fit(X_train,
                    y_train,
                    validation_split=0.2,
                    epochs=50,
                    batch_size = 64,
                    verbose=1,
                    callbacks=[learning_rate_annealer],validation_data=(X_test,y_test))



print(history.history.keys())
# Out:
# Epoch 1/50
# 21/21 [==============================] - ETA: 0s - loss: 2.4745 - accuracy: 0.5364WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 68s 3s/step - loss: 2.4745 - accuracy: 0.5364 - val_loss: 0.6817 - val_accuracy: 0.5212 - lr: 0.0010
# Epoch 2/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7938 - accuracy: 0.5569WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.7938 - accuracy: 0.5569 - val_loss: 0.7724 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 3/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6978 - accuracy: 0.5721WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] -
- val_accuracy: 0.7606 - lr: 0.0010
# Epoch 27/50
# 21/21 [==============================] - ETA: 0s - loss: 0.2714 - accuracy: 0.8869WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 45s 2s/step - loss: 0.2714 - accuracy: 0.8869 - val_loss: 0.7036 - val_accuracy: 0.7667 - lr: 0.0010
# Epoch 28/50
# 21/21 [==============================] - ETA: 0s - loss: 0.2542 - accuracy: 0.8862WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 47s 2s/step - loss: 0.2542 - accuracy: 0.8862 - val_loss: 0.7238 - val_accuracy: 0.7758 - lr: 0.0010
# Epoch 29/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1993 - accuracy: 0.9044WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 47s 2s/step - loss: 0.1993 - accuracy: 0.9044 - val_loss: 0.9157 - val_accuracy: 0.7727 - lr: 0.0010
# Epoch 30/50
# 21/21 [==============================] - ETA: 0s - loss: 0.3526 - accuracy: 0.8869WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 49s 2s/step - loss: 0.3526 - accuracy: 0.8869 - val_loss: 0.8885 - val_accuracy: 0.7788 - lr: 0.0010
# Epoch 31/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1550 - accuracy: 0.9347WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 48s 2s/step - loss: 0.1550 - accuracy: 0.9347 - val_loss: 1.1526 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 32/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1920 - accuracy: 0.9181WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 45s 2s/step - loss: 0.1920 - accuracy: 0.9181 - val_loss: 1.6434 - val_accuracy: 0.7818 - lr: 0.0010
# Epoch 33/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1787 - accuracy: 0.9249WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 45s 2s/step - loss: 0.1787 - accuracy: 0.9249 - val_loss: 1.8038 - val_accuracy: 0.7697 - lr: 0.0010
# Epoch 34/50
# 21/21 [==============================] - ETA: 0s - loss: 0.2296 - accuracy: 0.9082WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 47s 2s/step - loss: 0.2296 - accuracy: 0.9082 - val_loss: 1.0960 - val_accuracy: 0.7576 - lr: 0.0010
# Epoch 35/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1364 - accuracy: 0.9476WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 47s 2s/step - loss: 0.1364 - accuracy: 0.9476 - val_loss: 1.3966 - val_accuracy: 0.7758 - lr: 0.0010
# Epoch 36/50
# 21/21 [==============================] - ETA: 0s - loss: 0.2112 - accuracy: 0.9165WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 47s 2s/step - loss: 0.2112 - accuracy: 0.9165 - val_loss: 1.5018 - val_accuracy: 0.7576 - lr: 0.0010
# Epoch 37/50
# 21/21 [==============================] - ETA: 0s - loss: 0.0979 - accuracy: 0.9628WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 45s 2s/step - loss: 0.0979 - accuracy: 0.9628 - val_loss: 1.8819 - val_accuracy: 0.7697 - lr: 0.0010
# Epoch 38/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1432 - accuracy: 0.9401WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 45s 2s/step - loss: 0.1432 - accuracy: 0.9401 - val_loss: 1.5038 - val_accuracy: 0.7364 - lr: 0.0010
# Epoch 39/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1795 - accuracy: 0.9401WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 43s 2s/step - loss: 0.1795 - accuracy: 0.9401 - val_loss: 1.2284 - val_accuracy: 0.7273 - lr: 0.0010
# Epoch 40/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1040 - accuracy: 0.9689WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 44s 2s/step - loss: 0.1040 - accuracy: 0.9689 - val_loss: 1.6856 - val_accuracy: 0.7909 - lr: 0.0010
# Epoch 41/50
# 21/21 [==============================] - ETA: 0s - loss: 0.0525 - accuracy: 0.9848WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 46s 2s/step - loss: 0.0525 - accuracy: 0.9848 - val_loss: 2.3544 - val_accuracy: 0.7576 - lr: 0.0010
# Epoch 42/50
# 21/21 [==============================] - ETA: 0s - loss: 0.0868 - accuracy: 0.9742WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 46s 2s/step - loss: 0.0868 - accuracy: 0.9742 - val_loss: 2.5316 - val_accuracy: 0.7909 - lr: 0.0010
# Epoch 43/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1506 - accuracy: 0.9575WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 49s 2s/step - loss: 0.1506 - accuracy: 0.9575 - val_loss: 2.3305 - val_accuracy: 0.7455 - lr: 0.0010
# Epoch 44/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1603 - accuracy: 0.9575WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 46s 2s/step - loss: 0.1603 - accuracy: 0.9575 - val_loss: 1.9768 - val_accuracy: 0.7515 - lr: 0.0010
# Epoch 45/50
# 21/21 [==============================] - ETA: 0s - loss: 0.0300 - accuracy: 0.9924WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 46s 2s/step - loss: 0.0300 - accuracy: 0.9924 - val_loss: 2.7389 - val_accuracy: 0.7333 - lr: 0.0010
# Epoch 46/50
# 21/21 [==============================] - ETA: 0s - loss: 0.2174 - accuracy: 0.9575WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 45s 2s/step - loss: 0.2174 - accuracy: 0.9575 - val_loss: 2.0202 - val_accuracy: 0.7515 - lr: 0.0010
# Epoch 47/50
# 21/21 [==============================] - ETA: 0s - loss: 0.0182 - accuracy: 0.9947WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 44s 2s/step - loss: 0.0182 - accuracy: 0.9947 - val_loss: 1.6952 - val_accuracy: 0.6879 - lr: 0.0010
# Epoch 48/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5287 - accuracy: 0.9120WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 43s 2s/step - loss: 0.5287 - accuracy: 0.9120 - val_loss: 1.2568 - val_accuracy: 0.7424 - lr: 0.0010
# Epoch 49/50
# 21/21 [==============================] - ETA: 0s - loss: 0.0413 - accuracy: 0.9924WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 45s 2s/step - loss: 0.0413 - accuracy: 0.9924 - val_loss: 2.0127 - val_accuracy: 0.7333 - lr: 0.0010
# Epoch 50/50
# 21/21 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 0.9985WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 45s 2s/step - loss: 0.0095 - accuracy: 0.9985 - val_loss: 2.7753 - val_accuracy: 0.7152 - lr: 0.0010
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')

plt.legend(['Train', 'Val'], loc='upper left')
plt.show()


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')

plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

y_pred = model.predict(X_test)
y_test_labels = ['benign' if label == 0 else 'malignant' for label in y_test]
y_pred_labels = ['benign' if label < 0.5 else 'malignant' for label in y_pred]

conf_matrix = confusion_matrix(y_test_labels, y_pred_labels)

plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", 
            xticklabels=['benign', 'malignant'], 
            yticklabels=['benign', 'malignant'])
plt.title("Matriz de Confusión")
plt.xlabel("Predicciones")
plt.ylabel("Valores Verdaderos")
plt.show()
# Out:
# 11/11 [==============================] - 2s 213ms/step
