# %% [markdown]
# <a href="https://colab.research.google.com/github/dangalmar/TFG_Imagenes_Medicas/blob/main/Tratamiento_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler

import os

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from glob import glob
import seaborn as sns
from PIL import Image

# %%
folder_benign_train = '../new_data/train/benign'
folder_malignant_train = '../new_data/train/malignant'

folder_benign_test = '../new_data/test/benign'
folder_malignant_test = '../new_data/test/malignant'

read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))

# Load in training pictures
ims_benign = [read(os.path.join(folder_benign_train, filename)) for filename in os.listdir(folder_benign_train)]
X_benign = np.array(ims_benign, dtype='uint8')
ims_malignant = [read(os.path.join(folder_malignant_train, filename)) for filename in os.listdir(folder_malignant_train)]
X_malignant = np.array(ims_malignant, dtype='uint8')

# Load in testing pictures
ims_benign = [read(os.path.join(folder_benign_test, filename)) for filename in os.listdir(folder_benign_test)]
X_benign_test = np.array(ims_benign, dtype='uint8')
ims_malignant = [read(os.path.join(folder_malignant_test, filename)) for filename in os.listdir(folder_malignant_test)]
X_malignant_test = np.array(ims_malignant, dtype='uint8')

# Create labels
y_benign = np.zeros(X_benign.shape[0])
y_malignant = np.ones(X_malignant.shape[0])

y_benign_test = np.zeros(X_benign_test.shape[0])
y_malignant_test = np.ones(X_malignant_test.shape[0])


# Merge data
X_train = np.concatenate((X_benign, X_malignant), axis = 0)
y_train = np.concatenate((y_benign, y_malignant), axis = 0)

X_test = np.concatenate((X_benign_test, X_malignant_test), axis = 0)
y_test = np.concatenate((y_benign_test, y_malignant_test), axis = 0)

# Shuffle data
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
y_train = y_train[s]

s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
y_test = y_test[s]

# %%
# Display first 15 images of moles, and how they are classified
w=40
h=30
fig=plt.figure(figsize=(12, 8))
columns = 5
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if y_train[i] == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(X_train[i], interpolation='nearest')

plt.show()

# %%
plt.bar(0, y_train[np.where(y_train == 0)].shape[0], label = 'benign')
plt.bar(1, y_train[np.where(y_train == 1)].shape[0], label = 'malignant')
plt.legend()
plt.title("Training Data")
plt.show()

plt.bar(0, y_test[np.where(y_test == 0)].shape[0], label = 'benign')
plt.bar(1, y_test[np.where(y_test == 1)].shape[0], label = 'malignant')
plt.legend()
plt.title("Test Data")
plt.show()

# %%
## Normalize by dividing by RGB value
X_train = X_train/255
X_test = X_test/255

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

# %%
from keras import regularizers

model = Sequential()

# Input Layer
model.add(Conv2D(32, (3,3), activation='relu', kernel_regularizer=regularizers.l2(0.01), input_shape=(224, 224, 3))) 
model.add(MaxPooling2D(pool_size=(2, 2)))

# Bloque 1 
model.add(Conv2D(64, (3,3), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Bloque 2
model.add(Conv2D(128, (3,3), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Bloque 3
model.add(Conv2D(256, (3,3), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Capas totalmente conectadas
model.add(Flatten())
model.add(Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01)))

# Capa de salida
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 222, 222, 32)      896
#
#  max_pooling2d_8 (MaxPooling  (None, 111, 111, 32)     0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_9 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 52, 52, 128)       73856
#
#  max_pooling2d_10 (MaxPoolin  (None, 26, 26, 128)      0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 24, 24, 256)       295168
#
#  max_pooling2d_11 (MaxPoolin  (None, 12, 12, 256)      0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 36864)             0
#
#  dense_4 (Dense)             (None, 512)               18874880
#
#  dense_5 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 19,263,809
# Trainable params: 19,263,809
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ReduceLROnPlateau
learning_rate_annealer = ReduceLROnPlateau(monitor='val_acc',mode='max',
                                          patience=3,
                                          verbose=1,
                                          factor=0.5,
                                          min_lr = 1e-4)


history = model.fit(X_train,
                    y_train,
                    validation_split=0.2,
                    epochs=50,
                    batch_size = 64,
                    verbose=1,
                    callbacks=[learning_rate_annealer],validation_data=(X_test,y_test))



print(history.history.keys())
# Out:
# Epoch 1/50
# 21/21 [==============================] - ETA: 0s - loss: 5.4570 - accuracy: 0.5690WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 57s 2s/step - loss: 5.4570 - accuracy: 0.5690 - val_loss: 2.7502 - val_accuracy: 0.5788 - lr: 0.0010
# Epoch 2/50
# 21/21 [==============================] - ETA: 0s - loss: 1.8657 - accuracy: 0.7018WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 45s 2s/step - loss: 1.8657 - accuracy: 0.7018 - val_loss: 1.3394 - val_accuracy: 0.7061 - lr: 0.0010
# Epoch 3/50
# 21/21 [==============================] - ETA: 0s - loss: 1.1687 - accuracy: 0.7238WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 44s 2s/step - loss: 1.1687 - accuracy: 0.7238 - val_loss: 1.1332 - val_accuracy: 0.6152 - lr: 0.0010
# Epoch 4/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9724 - accuracy: 0.7337WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 45s 2s/step - loss: 0.9724 - accuracy: 0.7337 - val_loss: 0.9807 - val_accuracy: 0.7000 - lr: 0.0010
# Epoch 5/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8670 - accuracy: 0.7496WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 46s 2s/step - loss: 0.8670 - accuracy: 0.7496 - val_loss: 0.8390 - val_accuracy: 0.7121 - lr: 0.0010
# Epoch 6/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7803 - accuracy: 0.7701WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 45s 2s/step - loss: 0.7803 - accuracy: 0.7701 - val_loss: 0.8182 - val_accuracy: 0.7606 - lr: 0.0010
# Epoch 7/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7778 - accuracy: 0.7436WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 46s 2s/step - loss: 0.7778 - accuracy: 0.7436 - val_loss: 0.8257 - val_accuracy: 0.7485 - lr: 0.0010
# Epoch 8/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7441 - accuracy: 0.7716WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 46s 2s/step - loss: 0.7441 - accuracy: 0.7716 - val_loss: 0.7196 - val_accuracy: 0.7545 - lr: 0.0010
# Epoch 9/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6464 - accuracy: 0.7891WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 45s 2s/step - loss: 0.6464 - accuracy: 0.7891 - val_loss: 0.6536 - val_accuracy: 0.7667 - lr: 0.0010
# Epoch 10/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6198 - accuracy: 0.7967WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 42s 2s/step - loss: 0.6198 - accuracy: 0.7967 - val_loss: 0.6631 - val_accuracy: 0.7576 - lr: 0.0010
# Epoch 11/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6523 - accuracy: 0.7701WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 42s 2s/step - loss: 0.6523 - accuracy: 0.7701 - val_loss: 0.6859 - val_accuracy: 0.7576 - lr: 0.0010
# Epoch 12/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6221 - accuracy: 0.7807WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 43s 2s/step - loss: 0.6221 - accuracy: 0.7807 - val_loss: 0.6451 - val_accuracy: 0.7455 - lr: 0.0010
# Epoch 13/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5887 - accuracy: 0.7876WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 43s 2s/step - loss: 0.5887 - accuracy: 0.7876 - val_loss: 0.6383 - val_accuracy: 0.7576 - lr: 0.0010
# Epoch 14/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5769 - accuracy: 0.7898WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 43s 2s/step - loss: 0.5769 - accuracy: 0.7898 - val_loss: 0.6084 - val_accuracy: 0.7576 - lr: 0.0010
# Epoch 15/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5536 - accuracy: 0.7967WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 44s 2s/step - loss: 0.5536 - accuracy: 0.7967 - val_loss: 0.6070 - val_accuracy: 0.7727 - lr: 0.0010
# Epoch 16/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5785 - accuracy: 0.7800WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 58s 3s/step - loss: 0.5785 - accuracy: 0.7800 - val_loss: 0.5921 - val_accuracy: 0.7727 - lr: 0.0010
# Epoch 17/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5857 - accuracy: 0.7860WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 59s 3s/step - loss: 0.5857 - accuracy: 0.7860 - val_loss: 0.5882 - val_accuracy: 0.7667 - lr: 0.0010
# Epoch 18/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5389 - accuracy: 0.7989WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 59s 3s/step - loss: 0.5389 - accuracy: 0.7989 - val_loss: 0.5590 - val_accuracy: 0.7667 - lr: 0.0010
# Epoch 19/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5298 - accuracy: 0.8005WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 47s 2s/step - loss: 0.5298 - accuracy: 0.8005 - val_loss: 0.5540 - val_accuracy: 0.7636 - lr: 0.0010
# Epoch 20/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5340 - accuracy: 0.8042WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 3s/step - loss: 0.5340 - accuracy: 0.8042 - val_loss: 0.5704 - val_accuracy: 0.7576 - lr: 0.0010
# Epoch 21/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5434 - accuracy: 0.7936WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 56s 3s/step - loss: 0.5434 - accuracy: 0.7936 - val_loss: 0.5517 - val_accuracy: 0.7636 - lr: 0.0010
# Epoch 22/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5152 - accuracy: 0.8012WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 3s/step - loss: 0.5152 - accuracy: 0.8012 - val_loss: 0.5418 - val_accuracy: 0.7636 - lr: 0.0010
# Epoch 23/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5260 - accuracy: 0.8005WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.5260 - accuracy: 0.8005 - val_loss: 0.5548 - val_accuracy: 0.7576 - lr: 0.0010
# Epoch 24/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5346 - accuracy: 0.7936WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 57s 3s/step - loss: 0.5346 - accuracy: 0.7936 - val_loss: 0.5504 - val_accuracy: 0.7697 - lr: 0.0010
# Epoch 25/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5144 - accuracy: 0.7997WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 52s 2s/step - loss: 0.5144 - accuracy: 0.7997 - val_loss: 0.5406 - val_accuracy: 0.7758 - lr: 0.0010
# Epoch 26/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5139 - accuracy: 0.7936WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 56s 3s/step - loss: 0.5139 - accuracy: 0.7936 - val_loss: 0.6005 - val_accuracy: 0.7303 - lr: 0.0010
# Epoch 27/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5478 - accuracy: 0.7876WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 56s 3s/step - loss: 0.5478 - accuracy: 0.7876 - val_loss: 0.5504 - val_accuracy: 0.7697 - lr: 0.0010
# Epoch 28/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5191 - accuracy: 0.7989WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 57s 3s/step - loss: 0.5191 - accuracy: 0.7989 - val_loss: 0.5593 - val_accuracy: 0.7455 - lr: 0.0010
# Epoch 29/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5090 - accuracy: 0.8012WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 57s 3s/step - loss: 0.5090 - accuracy: 0.8012 - val_loss: 0.5319 - val_accuracy: 0.7636 - lr: 0.0010
# Epoch 30/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4971 - accuracy: 0.8035WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 57s 3s/step - loss: 0.4971 - accuracy: 0.8035 - val_loss: 0.5322 - val_accuracy: 0.7606 - lr: 0.0010
# Epoch 31/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4994 - accuracy: 0.7989WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 56s 3s/step - loss: 0.4994 - accuracy: 0.7989 - val_loss: 0.5276 - val_accuracy: 0.7758 - lr: 0.0010
# Epoch 32/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5415 - accuracy: 0.7731WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 55s 3s/step - loss: 0.5415 - accuracy: 0.7731 - val_loss: 0.5340 - val_accuracy: 0.7576 - lr: 0.0010
# Epoch 33/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5265 - accuracy: 0.7921WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 56s 3s/step - loss: 0.5265 - accuracy: 0.7921 - val_loss: 0.5508 - val_accuracy: 0.7697 - lr: 0.0010
# Epoch 34/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5250 - accuracy: 0.7929WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 57s 3s/step - loss: 0.5250 - accuracy: 0.7929 - val_loss: 0.5252 - val_accuracy: 0.7727 - lr: 0.0010
# Epoch 35/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4900 - accuracy: 0.8073WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 56s 3s/step - loss: 0.4900 - accuracy: 0.8073 - val_loss: 0.5223 - val_accuracy: 0.7788 - lr: 0.0010
# Epoch 36/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5045 - accuracy: 0.7997WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 57s 3s/step - loss: 0.5045 - accuracy: 0.7997 - val_loss: 0.5488 - val_accuracy: 0.7667 - lr: 0.0010
# Epoch 37/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5302 - accuracy: 0.7845WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 56s 3s/step - loss: 0.5302 - accuracy: 0.7845 - val_loss: 0.5275 - val_accuracy: 0.7697 - lr: 0.0010
# Epoch 38/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4971 - accuracy: 0.7989WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 57s 3s/step - loss: 0.4971 - accuracy: 0.7989 - val_loss: 0.5911 - val_accuracy: 0.7303 - lr: 0.0010
# Epoch 39/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4956 - accuracy: 0.7974WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 57s 3s/step - loss: 0.4956 - accuracy: 0.7974 - val_loss: 0.5685 - val_accuracy: 0.7606 - lr: 0.0010
# Epoch 40/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4965 - accuracy: 0.7974WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 56s 3s/step - loss: 0.4965 - accuracy: 0.7974 - val_loss: 0.5294 - val_accuracy: 0.7667 - lr: 0.0010
# Epoch 41/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4894 - accuracy: 0.7982WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 57s 3s/step - loss: 0.4894 - accuracy: 0.7982 - val_loss: 0.5038 - val_accuracy: 0.7758 - lr: 0.0010
# Epoch 42/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4760 - accuracy: 0.8058WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 57s 3s/step - loss: 0.4760 - accuracy: 0.8058 - val_loss: 0.5079 - val_accuracy: 0.7515 - lr: 0.0010
# Epoch 43/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4738 - accuracy: 0.8088WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 56s 3s/step - loss: 0.4738 - accuracy: 0.8088 - val_loss: 0.5384 - val_accuracy: 0.7485 - lr: 0.0010
# Epoch 44/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4965 - accuracy: 0.7989WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 57s 3s/step - loss: 0.4965 - accuracy: 0.7989 - val_loss: 0.4971 - val_accuracy: 0.7697 - lr: 0.0010
# Epoch 45/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4761 - accuracy: 0.8065WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 56s 3s/step - loss: 0.4761 - accuracy: 0.8065 - val_loss: 0.5120 - val_accuracy: 0.7727 - lr: 0.0010
# Epoch 46/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5115 - accuracy: 0.8050WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 56s 3s/step - loss: 0.5115 - accuracy: 0.8050 - val_loss: 0.5459 - val_accuracy: 0.7455 - lr: 0.0010
# Epoch 47/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4887 - accuracy: 0.7974WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 54s 3s/step - loss: 0.4887 - accuracy: 0.7974 - val_loss: 0.5082 - val_accuracy: 0.7667 - lr: 0.0010
# Epoch 48/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4814 - accuracy: 0.8065WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 57s 3s/step - loss: 0.4814 - accuracy: 0.8065 - val_loss: 0.5034 - val_accuracy: 0.7545 - lr: 0.0010
# Epoch 49/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4840 - accuracy: 0.8126WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 57s 3s/step - loss: 0.4840 - accuracy: 0.8126 - val_loss: 0.5797 - val_accuracy: 0.7667 - lr: 0.0010
# Epoch 50/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4941 - accuracy: 0.8012WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 21/21 [==============================] - 57s 3s/step - loss: 0.4941 - accuracy: 0.8012 - val_loss: 0.5149 - val_accuracy: 0.7606 - lr: 0.0010
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')

plt.legend(['Train', 'Val'], loc='upper left')
plt.show()


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')

plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
