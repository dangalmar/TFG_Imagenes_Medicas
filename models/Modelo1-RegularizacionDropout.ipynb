# %% [markdown]
# <a href="https://colab.research.google.com/github/dangalmar/TFG_Imagenes_Medicas/blob/main/Tratamiento_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler

import os

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from glob import glob
import seaborn as sns
from PIL import Image

# %%
folder_benign_train = '../new_data/train/benign'
folder_malignant_train = '../new_data/train/malignant'

folder_benign_test = '../new_data/test/benign'
folder_malignant_test = '../new_data/test/malignant'

read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))

# Load in training pictures
ims_benign = [read(os.path.join(folder_benign_train, filename)) for filename in os.listdir(folder_benign_train)]
X_benign = np.array(ims_benign, dtype='uint8')
ims_malignant = [read(os.path.join(folder_malignant_train, filename)) for filename in os.listdir(folder_malignant_train)]
X_malignant = np.array(ims_malignant, dtype='uint8')

# Load in testing pictures
ims_benign = [read(os.path.join(folder_benign_test, filename)) for filename in os.listdir(folder_benign_test)]
X_benign_test = np.array(ims_benign, dtype='uint8')
ims_malignant = [read(os.path.join(folder_malignant_test, filename)) for filename in os.listdir(folder_malignant_test)]
X_malignant_test = np.array(ims_malignant, dtype='uint8')

# Create labels
y_benign = np.zeros(X_benign.shape[0])
y_malignant = np.ones(X_malignant.shape[0])

y_benign_test = np.zeros(X_benign_test.shape[0])
y_malignant_test = np.ones(X_malignant_test.shape[0])


# Merge data
X_train = np.concatenate((X_benign, X_malignant), axis = 0)
y_train = np.concatenate((y_benign, y_malignant), axis = 0)

X_test = np.concatenate((X_benign_test, X_malignant_test), axis = 0)
y_test = np.concatenate((y_benign_test, y_malignant_test), axis = 0)

# Shuffle data
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
y_train = y_train[s]

s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
y_test = y_test[s]

# %%
# Display first 15 images of moles, and how they are classified
w=40
h=30
fig=plt.figure(figsize=(12, 8))
columns = 5
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if y_train[i] == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(X_train[i], interpolation='nearest')

plt.show()

# %%
plt.bar(0, y_train[np.where(y_train == 0)].shape[0], label = 'benign')
plt.bar(1, y_train[np.where(y_train == 1)].shape[0], label = 'malignant')
plt.legend()
plt.title("Training Data")
plt.show()

plt.bar(0, y_test[np.where(y_test == 0)].shape[0], label = 'benign')
plt.bar(1, y_test[np.where(y_test == 1)].shape[0], label = 'malignant')
plt.legend()
plt.title("Test Data")
plt.show()

# %%
## Normalize by dividing by RGB value
X_train = X_train/255
X_test = X_test/255

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()

# Input Layer
model.add(Conv2D(32,(3,3),activation='relu',input_shape = (224,224,3))) 
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# Bloack 1 
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# Block 2
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# Block 3
model.add(Conv2D(256,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# Fully Connected layers 
model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.2))

# Output layer
model.add(Dense(1,activation='sigmoid'))
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 222, 222, 32)      896
#
#  max_pooling2d_4 (MaxPooling  (None, 111, 111, 32)     0
#  2D)
#
#  dropout_5 (Dropout)         (None, 111, 111, 32)      0
#
#  conv2d_5 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_5 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 54, 54, 64)        0
#
#  conv2d_6 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_6 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  dropout_7 (Dropout)         (None, 26, 26, 128)       0
#
#  conv2d_7 (Conv2D)           (None, 24, 24, 256)       295168
#
#  max_pooling2d_7 (MaxPooling  (None, 12, 12, 256)      0
#  2D)
#
#  dropout_8 (Dropout)         (None, 12, 12, 256)       0
#
#  flatten_1 (Flatten)         (None, 36864)             0
#
#  dense_2 (Dense)             (None, 512)               18874880
#
#  dropout_9 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 19,263,809
# Trainable params: 19,263,809
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ReduceLROnPlateau
learning_rate_annealer = ReduceLROnPlateau(monitor='val_acc',mode='max',
                                          patience=3,
                                          verbose=1,
                                          factor=0.5,
                                          min_lr = 1e-4)


history = model.fit(X_train,
                    y_train,
                    validation_split=0.2,
                    epochs=50,
                    batch_size = 64,
                    verbose=1,
                    callbacks=[learning_rate_annealer],validation_data=(X_test,y_test))



print(history.history.keys())
# Out:
# Epoch 1/50
# 42/42 [==============================] - ETA: 0s - loss: 0.7980 - accuracy: 0.5605WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 120s 3s/step - loss: 0.7980 - accuracy: 0.5605 - val_loss: 0.6168 - val_accuracy: 0.6879 - lr: 0.0010
# Epoch 2/50
# 42/42 [==============================] - ETA: 0s - loss: 0.5388 - accuracy: 0.7220WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 105s 2s/step - loss: 0.5388 - accuracy: 0.7220 - val_loss: 0.5172 - val_accuracy: 0.7788 - lr: 0.0010
# Epoch 3/50
# 42/42 [==============================] - ETA: 0s - loss: 0.4613 - accuracy: 0.7710WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 108s 3s/step - loss: 0.4613 - accuracy: 0.7710 - val_loss: 0.6062 - val_accuracy: 0.6212 - lr: 0.0010
# Epoch 4/50
# 42/42 [==============================] - ETA: 0s - loss: 0.4253 - accuracy: 0.7884WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 106s 3s/step - loss: 0.4253 - accuracy: 0.7884 - val_loss: 0.4758 - val_accuracy: 0.7485 - lr: 0.0010
# Epoch 5/50
# 42/42 [==============================] - ETA: 0s - loss: 0.4021 - accuracy: 0.7967WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 109s 3s/step - loss: 0.4021 - accuracy: 0.7967 - val_loss: 0.4899 - val_accuracy: 0.7394 - lr: 0.0010
# Epoch 6/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3935 - accuracy: 0.7998WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 105s 3s/step - loss: 0.3935 - accuracy: 0.7998 - val_loss: 0.6089 - val_accuracy: 0.6470 - lr: 0.0010
# Epoch 7/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3833 - accuracy: 0.8130WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 106s 3s/step - loss: 0.3833 - accuracy: 0.8130 - val_loss: 0.3763 - val_accuracy: 0.8076 - lr: 0.0010
# Epoch 8/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3754 - accuracy: 0.8123WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 102s 2s/step - loss: 0.3754 - accuracy: 0.8123 - val_loss: 0.4979 - val_accuracy: 0.7591 - lr: 0.0010
# Epoch 9/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3653 - accuracy: 0.8142WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 102s 2s/step - loss: 0.3653 - accuracy: 0.8142 - val_loss: 0.4040 - val_accuracy: 0.8091 - lr: 0.0010
# Epoch 10/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3794 - accuracy: 0.8187WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 103s 2s/step - loss: 0.3794 - accuracy: 0.8187 - val_loss: 0.5114 - val_accuracy: 0.7121 - lr: 0.0010
# Epoch 11/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3478 - accuracy: 0.8259WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 100s 2s/step - loss: 0.3478 - accuracy: 0.8259 - val_loss: 0.4365 - val_accuracy: 0.8030 - lr: 0.0010
# Epoch 12/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3300 - accuracy: 0.8381WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 99s 2s/step - loss: 0.3300 - accuracy: 0.8381 - val_loss: 0.4853 - val_accuracy: 0.7652 - lr: 0.0010
# Epoch 13/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3444 - accuracy: 0.8426WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 100s 2s/step - loss: 0.3444 - accuracy: 0.8426 - val_loss: 0.3802 - val_accuracy: 0.8091 - lr: 0.0010
# Epoch 14/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3276 - accuracy: 0.8350WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 101s 2s/step - loss: 0.3276 - accuracy: 0.8350 - val_loss: 0.3793 - val_accuracy: 0.8121 - lr: 0.0010
# Epoch 15/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3317 - accuracy: 0.8324WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 98s 2s/step - loss: 0.3317 - accuracy: 0.8324 - val_loss: 0.4982 - val_accuracy: 0.7227 - lr: 0.0010
# Epoch 16/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3091 - accuracy: 0.8457WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 100s 2s/step - loss: 0.3091 - accuracy: 0.8457 - val_loss: 0.4188 - val_accuracy: 0.7758 - lr: 0.0010
# Epoch 17/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3114 - accuracy: 0.8529WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 98s 2s/step - loss: 0.3114 - accuracy: 0.8529 - val_loss: 0.4038 - val_accuracy: 0.8045 - lr: 0.0010
# Epoch 18/50
# 42/42 [==============================] - ETA: 0s - loss: 0.2967 - accuracy: 0.8567WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 98s 2s/step - loss: 0.2967 - accuracy: 0.8567 - val_loss: 0.3837 - val_accuracy: 0.8076 - lr: 0.0010
# Epoch 19/50
# 42/42 [==============================] - ETA: 0s - loss: 0.2832 - accuracy: 0.8714WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 98s 2s/step - loss: 0.2832 - accuracy: 0.8714 - val_loss: 0.4589 - val_accuracy: 0.7788 - lr: 0.0010
# Epoch 20/50
# 42/42 [==============================] - ETA: 0s - loss: 0.2962 - accuracy: 0.8639WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 99s 2s/step - loss: 0.2962 - accuracy: 0.8639 - val_loss: 0.4435 - val_accuracy: 0.7758 - lr: 0.0010
# Epoch 21/50
# 42/42 [==============================] - ETA: 0s - loss: 0.2804 - accuracy: 0.8703WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 99s 2s/step - loss: 0.2804 - accuracy: 0.8703 - val_loss: 0.4639 - val_accuracy: 0.7773 - lr: 0.0010
# Epoch 22/50
# 42/42 [==============================] - ETA: 0s - loss: 0.2616 - accuracy: 0.8805WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 102s 2s/step - loss: 0.2616 - accuracy: 0.8805 - val_loss: 0.4480 - val_accuracy: 0.7773 - lr: 0.0010
# Epoch 23/50
# 42/42 [==============================] - ETA: 0s - loss: 0.2312 - accuracy: 0.8927WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 99s 2s/step - loss: 0.2312 - accuracy: 0.8927 - val_loss: 0.3895 - val_accuracy: 0.8227 - lr: 0.0010
# Epoch 24/50
# 42/42 [==============================] - ETA: 0s - loss: 0.2695 - accuracy: 0.8805WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 100s 2s/step - loss: 0.2695 - accuracy: 0.8805 - val_loss: 0.3628 - val_accuracy: 0.8242 - lr: 0.0010
# Epoch 25/50
# 42/42 [==============================] - ETA: 0s - loss: 0.2151 - accuracy: 0.9006WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 99s 2s/step - loss: 0.2151 - accuracy: 0.9006 - val_loss: 0.4293 - val_accuracy: 0.8045 - lr: 0.0010
# Epoch 26/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1872 - accuracy: 0.9173WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 99s 2s/step - loss: 0.1872 - accuracy: 0.9173 - val_loss: 0.4152 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 27/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1933 - accuracy: 0.9154WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 98s 2s/step - loss: 0.1933 - accuracy: 0.9154 - val_loss: 0.4223 - val_accuracy: 0.8288 - lr: 0.0010
# Epoch 28/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1807 - accuracy: 0.9196WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 100s 2s/step - loss: 0.1807 - accuracy: 0.9196 - val_loss: 0.4658 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 29/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1760 - accuracy: 0.9234WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 100s 2s/step - loss: 0.1760 - accuracy: 0.9234 - val_loss: 0.6213 - val_accuracy: 0.7485 - lr: 0.0010
# Epoch 30/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1911 - accuracy: 0.9211WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 100s 2s/step - loss: 0.1911 - accuracy: 0.9211 - val_loss: 0.4444 - val_accuracy: 0.8091 - lr: 0.0010
# Epoch 31/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1477 - accuracy: 0.9416WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 101s 2s/step - loss: 0.1477 - accuracy: 0.9416 - val_loss: 0.4209 - val_accuracy: 0.8424 - lr: 0.0010
# Epoch 32/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1288 - accuracy: 0.9518WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 101s 2s/step - loss: 0.1288 - accuracy: 0.9518 - val_loss: 0.4881 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 33/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1368 - accuracy: 0.9443WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 110s 3s/step - loss: 0.1368 - accuracy: 0.9443 - val_loss: 0.4886 - val_accuracy: 0.8318 - lr: 0.0010
# Epoch 34/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1271 - accuracy: 0.9469WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 101s 2s/step - loss: 0.1271 - accuracy: 0.9469 - val_loss: 0.5039 - val_accuracy: 0.8409 - lr: 0.0010
# Epoch 35/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1253 - accuracy: 0.9526WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 111s 3s/step - loss: 0.1253 - accuracy: 0.9526 - val_loss: 0.5507 - val_accuracy: 0.8242 - lr: 0.0010
# Epoch 36/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1332 - accuracy: 0.9477WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 100s 2s/step - loss: 0.1332 - accuracy: 0.9477 - val_loss: 0.5241 - val_accuracy: 0.8379 - lr: 0.0010
# Epoch 37/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1340 - accuracy: 0.9473WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 100s 2s/step - loss: 0.1340 - accuracy: 0.9473 - val_loss: 0.6201 - val_accuracy: 0.8076 - lr: 0.0010
# Epoch 38/50
# 42/42 [==============================] - ETA: 0s - loss: 0.0877 - accuracy: 0.9651WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 101s 2s/step - loss: 0.0877 - accuracy: 0.9651 - val_loss: 0.6605 - val_accuracy: 0.8136 - lr: 0.0010
# Epoch 39/50
# 42/42 [==============================] - ETA: 0s - loss: 0.0830 - accuracy: 0.9678WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 99s 2s/step - loss: 0.0830 - accuracy: 0.9678 - val_loss: 0.7261 - val_accuracy: 0.8182 - lr: 0.0010
# Epoch 40/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1099 - accuracy: 0.9602WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 101s 2s/step - loss: 0.1099 - accuracy: 0.9602 - val_loss: 0.5351 - val_accuracy: 0.8273 - lr: 0.0010
# Epoch 41/50
# 42/42 [==============================] - ETA: 0s - loss: 0.0743 - accuracy: 0.9735WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 101s 2s/step - loss: 0.0743 - accuracy: 0.9735 - val_loss: 0.6953 - val_accuracy: 0.8106 - lr: 0.0010
# Epoch 42/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1151 - accuracy: 0.9583WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 100s 2s/step - loss: 0.1151 - accuracy: 0.9583 - val_loss: 0.5379 - val_accuracy: 0.8318 - lr: 0.0010
# Epoch 43/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1397 - accuracy: 0.9450WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 99s 2s/step - loss: 0.1397 - accuracy: 0.9450 - val_loss: 0.5897 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 44/50
# 42/42 [==============================] - ETA: 0s - loss: 0.0848 - accuracy: 0.9700WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 98s 2s/step - loss: 0.0848 - accuracy: 0.9700 - val_loss: 0.6250 - val_accuracy: 0.8439 - lr: 0.0010
# Epoch 45/50
# 42/42 [==============================] - ETA: 0s - loss: 0.0905 - accuracy: 0.9697WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 108s 3s/step - loss: 0.0905 - accuracy: 0.9697 - val_loss: 0.6468 - val_accuracy: 0.8242 - lr: 0.0010
# Epoch 46/50
# 42/42 [==============================] - ETA: 0s - loss: 0.0575 - accuracy: 0.9810WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 110s 3s/step - loss: 0.0575 - accuracy: 0.9810 - val_loss: 0.6939 - val_accuracy: 0.8303 - lr: 0.0010
# Epoch 47/50
# 42/42 [==============================] - ETA: 0s - loss: 0.0442 - accuracy: 0.9822WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 103s 2s/step - loss: 0.0442 - accuracy: 0.9822 - val_loss: 0.7005 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 48/50
# 42/42 [==============================] - ETA: 0s - loss: 0.0519 - accuracy: 0.9791WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 103s 2s/step - loss: 0.0519 - accuracy: 0.9791 - val_loss: 0.7254 - val_accuracy: 0.8288 - lr: 0.0010
# Epoch 49/50
# 42/42 [==============================] - ETA: 0s - loss: 0.0284 - accuracy: 0.9894WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 102s 2s/step - loss: 0.0284 - accuracy: 0.9894 - val_loss: 0.7636 - val_accuracy: 0.8303 - lr: 0.0010
# Epoch 50/50
# 42/42 [==============================] - ETA: 0s - loss: 0.0527 - accuracy: 0.9810WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 104s 2s/step - loss: 0.0527 - accuracy: 0.9810 - val_loss: 1.2345 - val_accuracy: 0.7894 - lr: 0.0010
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')

plt.legend(['Train', 'Val'], loc='upper left')
plt.show()


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')

plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
