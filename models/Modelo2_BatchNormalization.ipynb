# %% [markdown]
# <a href="https://colab.research.google.com/github/dangalmar/TFG_Imagenes_Medicas/blob/main/Tratamiento_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler

import os

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from glob import glob
import seaborn as sns
from PIL import Image

# %%
folder_benign_train = '../new_data/train/benign'
folder_malignant_train = '../new_data/train/malignant'

folder_benign_test = '../new_data/test/benign'
folder_malignant_test = '../new_data/test/malignant'

read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))

# Load in training pictures
ims_benign = [read(os.path.join(folder_benign_train, filename)) for filename in os.listdir(folder_benign_train)]
X_benign = np.array(ims_benign, dtype='uint8')
ims_malignant = [read(os.path.join(folder_malignant_train, filename)) for filename in os.listdir(folder_malignant_train)]
X_malignant = np.array(ims_malignant, dtype='uint8')

# Load in testing pictures
ims_benign = [read(os.path.join(folder_benign_test, filename)) for filename in os.listdir(folder_benign_test)]
X_benign_test = np.array(ims_benign, dtype='uint8')
ims_malignant = [read(os.path.join(folder_malignant_test, filename)) for filename in os.listdir(folder_malignant_test)]
X_malignant_test = np.array(ims_malignant, dtype='uint8')

# Create labels
y_benign = np.zeros(X_benign.shape[0])
y_malignant = np.ones(X_malignant.shape[0])

y_benign_test = np.zeros(X_benign_test.shape[0])
y_malignant_test = np.ones(X_malignant_test.shape[0])


# Merge data
X_train = np.concatenate((X_benign, X_malignant), axis = 0)
y_train = np.concatenate((y_benign, y_malignant), axis = 0)

X_test = np.concatenate((X_benign_test, X_malignant_test), axis = 0)
y_test = np.concatenate((y_benign_test, y_malignant_test), axis = 0)

# Shuffle data
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
y_train = y_train[s]

s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
y_test = y_test[s]

# %%
# Display first 15 images of moles, and how they are classified
w=40
h=30
fig=plt.figure(figsize=(12, 8))
columns = 5
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if y_train[i] == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(X_train[i], interpolation='nearest')

plt.show()

# %%
plt.bar(0, y_train[np.where(y_train == 0)].shape[0], label = 'benign')
plt.bar(1, y_train[np.where(y_train == 1)].shape[0], label = 'malignant')
plt.legend()
plt.title("Training Data")
plt.show()

plt.bar(0, y_test[np.where(y_test == 0)].shape[0], label = 'benign')
plt.bar(1, y_test[np.where(y_test == 1)].shape[0], label = 'malignant')
plt.legend()
plt.title("Test Data")
plt.show()

# %%
## Normalize by dividing by RGB value
X_train = X_train/255
X_test = X_test/255

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()

# Input Layer
model.add(Conv2D(32,(3,3),activation='relu',input_shape = (224,224,3))) 
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# Bloack 1 
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
# Block 2
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
# Block 3
model.add(Conv2D(256,(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# Fully Connected layers 
model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

# Output layer
model.add(Dense(2,activation='sigmoid'))
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 222, 222, 32)      896
#
#  batch_normalization_5 (Batc  (None, 222, 222, 32)     128
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 111, 111, 32)     0
#  2D)
#
#  dropout_5 (Dropout)         (None, 111, 111, 32)      0
#
#  conv2d_5 (Conv2D)           (None, 109, 109, 64)      18496
#
#  batch_normalization_6 (Batc  (None, 109, 109, 64)     256
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 54, 54, 64)        0
#
#  conv2d_6 (Conv2D)           (None, 52, 52, 128)       73856
#
#  batch_normalization_7 (Batc  (None, 52, 52, 128)      512
#  hNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  dropout_7 (Dropout)         (None, 26, 26, 128)       0
#
#  conv2d_7 (Conv2D)           (None, 24, 24, 256)       295168
#
#  batch_normalization_8 (Batc  (None, 24, 24, 256)      1024
#  hNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 12, 12, 256)      0
#  2D)
#
#  dropout_8 (Dropout)         (None, 12, 12, 256)       0
#
#  flatten_1 (Flatten)         (None, 36864)             0
#
#  dense_2 (Dense)             (None, 512)               18874880
#
#  batch_normalization_9 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_9 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 19,268,290
# Trainable params: 19,266,306
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
from keras.callbacks import ReduceLROnPlateau
learning_rate_annealer = ReduceLROnPlateau(monitor='val_acc',mode='max',
                                          patience=3,
                                          verbose=1,
                                          factor=0.5,
                                          min_lr = 1e-4)


history = model_1.fit(X_train,
                    y_train,
                    validation_split=0.2,
                    epochs=50,
                    batch_size = 64,
                    verbose=1,
                    callbacks=[learning_rate_annealer],validation_data=(X_test,y_test))



print(history.history.keys())
# Out:
# Epoch 1/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3974 - accuracy: 0.8036WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 53s 1s/step - loss: 0.3974 - accuracy: 0.8036 - val_loss: 0.3906 - val_accuracy: 0.7970 - lr: 0.0010
# Epoch 2/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3825 - accuracy: 0.8111WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 33s 772ms/step - loss: 0.3825 - accuracy: 0.8111 - val_loss: 0.4211 - val_accuracy: 0.7803 - lr: 0.0010
# Epoch 3/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3914 - accuracy: 0.8104WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 32s 751ms/step - loss: 0.3914 - accuracy: 0.8104 - val_loss: 0.4505 - val_accuracy: 0.7864 - lr: 0.0010
# Epoch 4/50
# 42/42 [==============================] - ETA: 0s - loss: 0.4143 - accuracy: 0.7945WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 33s 779ms/step - loss: 0.4143 - accuracy: 0.7945 - val_loss: 0.3794 - val_accuracy: 0.8091 - lr: 0.0010
# Epoch 5/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3743 - accuracy: 0.8157WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 39s 946ms/step - loss: 0.3743 - accuracy: 0.8157 - val_loss: 0.3800 - val_accuracy: 0.8061 - lr: 0.0010
# Epoch 6/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3793 - accuracy: 0.8199WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 34s 813ms/step - loss: 0.3793 - accuracy: 0.8199 - val_loss: 0.3736 - val_accuracy: 0.8061 - lr: 0.0010
# Epoch 7/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3631 - accuracy: 0.8172WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 36s 849ms/step - loss: 0.3631 - accuracy: 0.8172 - val_loss: 0.3671 - val_accuracy: 0.8136 - lr: 0.0010
# Epoch 8/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3609 - accuracy: 0.8180WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 35s 830ms/step - loss: 0.3609 - accuracy: 0.8180 - val_loss: 0.3637 - val_accuracy: 0.8288 - lr: 0.0010
# Epoch 9/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3634 - accuracy: 0.8161WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 33s 795ms/step - loss: 0.3634 - accuracy: 0.8161 - val_loss: 0.3703 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 10/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3484 - accuracy: 0.8176WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 36s 858ms/step - loss: 0.3484 - accuracy: 0.8176 - val_loss: 0.3577 - val_accuracy: 0.8121 - lr: 0.0010
# Epoch 11/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3430 - accuracy: 0.8161WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 35s 842ms/step - loss: 0.3430 - accuracy: 0.8161 - val_loss: 0.3654 - val_accuracy: 0.8227 - lr: 0.0010
# Epoch 12/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3389 - accuracy: 0.8343WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 36s 869ms/step - loss: 0.3389 - accuracy: 0.8343 - val_loss: 0.4078 - val_accuracy: 0.7773 - lr: 0.0010
# Epoch 13/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3354 - accuracy: 0.8286WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 35s 824ms/step - loss: 0.3354 - accuracy: 0.8286 - val_loss: 0.3514 - val_accuracy: 0.8152 - lr: 0.0010
# Epoch 14/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3403 - accuracy: 0.8301WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 33s 776ms/step - loss: 0.3403 - accuracy: 0.8301 - val_loss: 0.3639 - val_accuracy: 0.8182 - lr: 0.0010
# Epoch 15/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3275 - accuracy: 0.8385WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 30s 725ms/step - loss: 0.3275 - accuracy: 0.8385 - val_loss: 0.3529 - val_accuracy: 0.8121 - lr: 0.0010
# Epoch 16/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3221 - accuracy: 0.8331WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 31s 733ms/step - loss: 0.3221 - accuracy: 0.8331 - val_loss: 0.4329 - val_accuracy: 0.7788 - lr: 0.0010
# Epoch 17/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3233 - accuracy: 0.8388WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 31s 745ms/step - loss: 0.3233 - accuracy: 0.8388 - val_loss: 0.3432 - val_accuracy: 0.8242 - lr: 0.0010
# Epoch 18/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3121 - accuracy: 0.8407WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 31s 745ms/step - loss: 0.3121 - accuracy: 0.8407 - val_loss: 0.3581 - val_accuracy: 0.8015 - lr: 0.0010
# Epoch 19/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3109 - accuracy: 0.8453WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 30s 720ms/step - loss: 0.3109 - accuracy: 0.8453 - val_loss: 0.3499 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 20/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3009 - accuracy: 0.8548WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 31s 745ms/step - loss: 0.3009 - accuracy: 0.8548 - val_loss: 0.3627 - val_accuracy: 0.7985 - lr: 0.0010
# Epoch 21/50
# 42/42 [==============================] - ETA: 0s - loss: 0.2759 - accuracy: 0.8635WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 32s 751ms/step - loss: 0.2759 - accuracy: 0.8635 - val_loss: 0.3896 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 22/50
# 42/42 [==============================] - ETA: 0s - loss: 0.2947 - accuracy: 0.8574WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 30s 726ms/step - loss: 0.2947 - accuracy: 0.8574 - val_loss: 0.3445 - val_accuracy: 0.8212 - lr: 0.0010
# Epoch 23/50
# 42/42 [==============================] - ETA: 0s - loss: 0.2742 - accuracy: 0.8627WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 31s 742ms/step - loss: 0.2742 - accuracy: 0.8627 - val_loss: 0.3724 - val_accuracy: 0.8136 - lr: 0.0010
# Epoch 24/50
# 42/42 [==============================] - ETA: 0s - loss: 0.2699 - accuracy: 0.8703WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 32s 755ms/step - loss: 0.2699 - accuracy: 0.8703 - val_loss: 0.3643 - val_accuracy: 0.8136 - lr: 0.0010
# Epoch 25/50
# 42/42 [==============================] - ETA: 0s - loss: 0.2687 - accuracy: 0.8699WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 32s 751ms/step - loss: 0.2687 - accuracy: 0.8699 - val_loss: 0.3734 - val_accuracy: 0.8212 - lr: 0.0010
# Epoch 26/50
# 42/42 [==============================] - ETA: 0s - loss: 0.2591 - accuracy: 0.8771WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 30s 715ms/step - loss: 0.2591 - accuracy: 0.8771 - val_loss: 0.3640 - val_accuracy: 0.8091 - lr: 0.0010
# Epoch 27/50
# 42/42 [==============================] - ETA: 0s - loss: 0.2597 - accuracy: 0.8612WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 31s 743ms/step - loss: 0.2597 - accuracy: 0.8612 - val_loss: 0.4391 - val_accuracy: 0.8197 - lr: 0.0010
# Epoch 28/50
# 42/42 [==============================] - ETA: 0s - loss: 0.2739 - accuracy: 0.8718WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 31s 748ms/step - loss: 0.2739 - accuracy: 0.8718 - val_loss: 0.3646 - val_accuracy: 0.8136 - lr: 0.0010
# Epoch 29/50
# 42/42 [==============================] - ETA: 0s - loss: 0.2566 - accuracy: 0.8802WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 34s 818ms/step - loss: 0.2566 - accuracy: 0.8802 - val_loss: 0.3575 - val_accuracy: 0.8152 - lr: 0.0010
# Epoch 30/50
# 42/42 [==============================] - ETA: 0s - loss: 0.2482 - accuracy: 0.8752WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 32s 751ms/step - loss: 0.2482 - accuracy: 0.8752 - val_loss: 0.4957 - val_accuracy: 0.7621 - lr: 0.0010
# Epoch 31/50
# 42/42 [==============================] - ETA: 0s - loss: 0.2878 - accuracy: 0.8597WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 34s 814ms/step - loss: 0.2878 - accuracy: 0.8597 - val_loss: 0.3585 - val_accuracy: 0.8091 - lr: 0.0010
# Epoch 32/50
# 42/42 [==============================] - ETA: 0s - loss: 0.2374 - accuracy: 0.8889WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 32s 760ms/step - loss: 0.2374 - accuracy: 0.8889 - val_loss: 0.3796 - val_accuracy: 0.8212 - lr: 0.0010
# Epoch 33/50
# 42/42 [==============================] - ETA: 0s - loss: 0.2326 - accuracy: 0.8881WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 32s 753ms/step - loss: 0.2326 - accuracy: 0.8881 - val_loss: 0.3418 - val_accuracy: 0.8197 - lr: 0.0010
# Epoch 34/50
# 42/42 [==============================] - ETA: 0s - loss: 0.2182 - accuracy: 0.8942WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 31s 744ms/step - loss: 0.2182 - accuracy: 0.8942 - val_loss: 0.3712 - val_accuracy: 0.8242 - lr: 0.0010
# Epoch 35/50
# 42/42 [==============================] - ETA: 0s - loss: 0.2002 - accuracy: 0.9090WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 32s 753ms/step - loss: 0.2002 - accuracy: 0.9090 - val_loss: 0.4031 - val_accuracy: 0.8227 - lr: 0.0010
# Epoch 36/50
# 42/42 [==============================] - ETA: 0s - loss: 0.2242 - accuracy: 0.8972WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 33s 784ms/step - loss: 0.2242 - accuracy: 0.8972 - val_loss: 0.3651 - val_accuracy: 0.8348 - lr: 0.0010
# Epoch 37/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1813 - accuracy: 0.9181WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 32s 754ms/step - loss: 0.1813 - accuracy: 0.9181 - val_loss: 0.3731 - val_accuracy: 0.8303 - lr: 0.0010
# Epoch 38/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1838 - accuracy: 0.9162WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 31s 745ms/step - loss: 0.1838 - accuracy: 0.9162 - val_loss: 0.4174 - val_accuracy: 0.8152 - lr: 0.0010
# Epoch 39/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9113WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 31s 741ms/step - loss: 0.1952 - accuracy: 0.9113 - val_loss: 0.3988 - val_accuracy: 0.8288 - lr: 0.0010
# Epoch 40/50
# 42/42 [==============================] - ETA: 0s - loss: 0.2780 - accuracy: 0.8756WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 30s 720ms/step - loss: 0.2780 - accuracy: 0.8756 - val_loss: 0.4387 - val_accuracy: 0.8061 - lr: 0.0010
# Epoch 41/50
# 42/42 [==============================] - ETA: 0s - loss: 0.2181 - accuracy: 0.9078WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 33s 775ms/step - loss: 0.2181 - accuracy: 0.9078 - val_loss: 0.4681 - val_accuracy: 0.7818 - lr: 0.0010
# Epoch 42/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1743 - accuracy: 0.9245WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 32s 756ms/step - loss: 0.1743 - accuracy: 0.9245 - val_loss: 0.4295 - val_accuracy: 0.8258 - lr: 0.0010
# Epoch 43/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1814 - accuracy: 0.9219WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 32s 764ms/step - loss: 0.1814 - accuracy: 0.9219 - val_loss: 0.3927 - val_accuracy: 0.8273 - lr: 0.0010
# Epoch 44/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1541 - accuracy: 0.9344WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 31s 748ms/step - loss: 0.1541 - accuracy: 0.9344 - val_loss: 0.4177 - val_accuracy: 0.8258 - lr: 0.0010
# Epoch 45/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1531 - accuracy: 0.9276WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 32s 754ms/step - loss: 0.1531 - accuracy: 0.9276 - val_loss: 0.4344 - val_accuracy: 0.8197 - lr: 0.0010
# Epoch 46/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1431 - accuracy: 0.9427WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 31s 731ms/step - loss: 0.1431 - accuracy: 0.9427 - val_loss: 0.4681 - val_accuracy: 0.8258 - lr: 0.0010
# Epoch 47/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1266 - accuracy: 0.9484WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 31s 746ms/step - loss: 0.1266 - accuracy: 0.9484 - val_loss: 0.4669 - val_accuracy: 0.8303 - lr: 0.0010
# Epoch 48/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1241 - accuracy: 0.9443WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 32s 766ms/step - loss: 0.1241 - accuracy: 0.9443 - val_loss: 0.4559 - val_accuracy: 0.8227 - lr: 0.0010
# Epoch 49/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1349 - accuracy: 0.9401WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 30s 725ms/step - loss: 0.1349 - accuracy: 0.9401 - val_loss: 0.4245 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 50/50
# 42/42 [==============================] - ETA: 0s - loss: 0.1415 - accuracy: 0.9427WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 42/42 [==============================] - 32s 755ms/step - loss: 0.1415 - accuracy: 0.9427 - val_loss: 0.4900 - val_accuracy: 0.8242 - lr: 0.0010
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')

plt.legend(['Train', 'Val'], loc='upper left')
plt.show()


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')

plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
